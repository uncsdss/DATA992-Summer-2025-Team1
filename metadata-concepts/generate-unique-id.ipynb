# %%
import os
import hashlib
import uuid
import csv
import json
import yaml  
from typing import Any, Callable

def generate_uuid(path: str) -> uuid.UUID:
    with open(path, 'rb') as f:
        content = f.read()
    digest = hashlib.sha256(content).hexdigest()
    return uuid.uuid5(uuid.NAMESPACE_URL, digest)

def prepend_to_file(path: str, text: str):
    with open(path, 'r+', encoding='utf-8') as f:
        original = f.read()
        f.seek(0)
        f.write(text + original)

def insert_structured(
    path: str,
    file_uuid: uuid.UUID,
    loader: Callable[..., Any],
    dumper: Callable[..., Any],
    is_yaml: bool = False
):
    with open(path, 'r', encoding='utf-8') as f:
        data = loader(f) or {}
    if not isinstance(data, dict):
        return
    if 'uuid' in data:
        return
    
    new_data = {'uuid': str(file_uuid), **data}

    with open(path, 'w', encoding='utf-8') as f:
        if is_yaml:
            dumper(new_data, f, sort_keys=False)
        else:
            dumper(new_data, f, indent=2)

    print(f"Generated key for {path}")

def insert_comment(path: str, file_uuid: uuid.UUID, marker: str):
    with open(path, 'r', encoding='utf-8') as f:
        head = f.read().splitlines()[:5]
    if any(line.startswith(marker) for line in head):
        return
    prepend_to_file(path, f"{marker} {file_uuid}\n")
    print(f"Generated key for {path}")

def process_files(repo_path: str, csv_output_path: str):

    handlers = {
        '.json': lambda p, u: insert_structured(p, u, json.load,   json.dump,    False),
        '.yml':  lambda p, u: insert_structured(p, u, yaml.safe_load,yaml.safe_dump, True),
        '.yaml': lambda p, u: insert_structured(p, u, yaml.safe_load,yaml.safe_dump, True),
        '.adoc': lambda p, u: insert_comment   (p, u, '// uuid:'),
    }

    mapping = []
    for root, _, files in os.walk(repo_path):
        for fname in files:
            ext = os.path.splitext(fname)[1].lower()
            if ext not in handlers:
                continue
            full = os.path.join(root, fname)
            u = generate_uuid(full)
            handlers[ext](full, u)
            rel = os.path.relpath(full, repo_path)
            mapping.append((str(u), rel))

    with open(csv_output_path, 'w', newline='', encoding='utf-8') as out:
        writer = csv.writer(out)
        writer.writerow(['uuid', 'relative_path'])
        writer.writerows(mapping)

    print(f"\n✅ Processed {len(mapping)} files → {csv_output_path}")

process_files(
    repo_path='../bluexp-dataset',
    csv_output_path='./uuid_file_map.csv'
)
# Out:
# Generated key for ../bluexp-dataset/_index.yml
# Generated key for ../bluexp-dataset/project.yml
# Generated key for ../bluexp-dataset/legal-notices.adoc
# Generated key for ../bluexp-dataset/api-cm/sidebar.yml
# Generated key for ../bluexp-dataset/credential/sidebar.yml
# Generated key for ../bluexp-dataset/credential/credential.json
# Generated key for ../bluexp-dataset/credential/credential-x-doc.json
# Generated key for ../bluexp-dataset/cbs/sidebar.yml
# Generated key for ../bluexp-dataset/cbs/cbs-x-doc.json
# Generated key for ../bluexp-dataset/cbs/cbs.json
# Generated key for ../bluexp-dataset/ipa/sidebar.yml
# Generated key for ../bluexp-dataset/ipa/ipa-x-doc.json
# Generated key for ../bluexp-dataset/ipa/ipa.json
# Generated key for ../bluexp-dataset/tenancy/sidebar.yml
# Generated key for ../bluexp-dataset/tenancy/tenancy-x-doc.json
# Generated key for ../bluexp-dataset/tenancy/tenancy.json
# Generated key for ../bluexp-dataset/platform/aa_concepts.adoc
# Generated key for ../bluexp-dataset/platform/create_user_token.adoc
# Generated key for ../bluexp-dataset/platform/http_details.adoc
# Generated key for ../bluexp-dataset/platform/get_identifiers.adoc
# Generated key for ../bluexp-dataset/platform/sidebar.yml
# Generated key for ../bluexp-dataset/platform/workflows_tasks.adoc
# Generated key for ../bluexp-dataset/platform/user_access_tokens.adoc
# Generated key for ../bluexp-dataset/platform/concepts.adoc
# Generated key for ../bluexp-dataset/platform/overview.adoc
# Generated key for ../bluexp-dataset/platform/register_service.adoc
# Generated key for ../bluexp-dataset/platform/api_explorer.adoc
# Generated key for ../bluexp-dataset/platform/get_nss_key.adoc
# Generated key for ../bluexp-dataset/platform/create_service_token.adoc
# Generated key for ../bluexp-dataset/platform/additional_considerations.adoc
# Generated key for ../bluexp-dataset/platform/use_rest_apis.adoc
# Generated key for ../bluexp-dataset/platform/connectors_clients.adoc
# Generated key for ../bluexp-dataset/platform/grant_types.adoc
# Generated key for ../bluexp-dataset/workflows/sidebar.yml
# Generated key for ../bluexp-dataset/copysync/sidebar.yml
# Generated key for ../bluexp-dataset/copysync/copysync-x-doc.json
# Generated key for ../bluexp-dataset/copysync/copysync.json
# Generated key for ../bluexp-dataset/fsx/sidebar.yml
# Generated key for ../bluexp-dataset/fsx/fsx.json
# Generated key for ../bluexp-dataset/fsx/fsx-x-doc.json
# Generated key for ../bluexp-dataset/audit/audit.json
# Generated key for ../bluexp-dataset/audit/sidebar.yml
# Generated key for ../bluexp-dataset/audit/audit-x-doc.json
# Generated key for ../bluexp-dataset/support/additional_resources.adoc
# Generated key for ../bluexp-dataset/support/sidebar.yml
# Generated key for ../bluexp-dataset/automate/blogs.adoc
# Generated key for ../bluexp-dataset/automate/sidebar.yml
# Generated key for ../bluexp-dataset/automate/overview.adoc
# Generated key for ../bluexp-dataset/tenancyv4/tenancyv4.yaml
# Generated key for ../bluexp-dataset/tenancyv4/sidebar.yml
# Generated key for ../bluexp-dataset/tenancyv4/tenancyv4-x-doc.yml
# Generated key for ../bluexp-dataset/dw/dw.json
# Generated key for ../bluexp-dataset/dw/sidebar.yml
# Generated key for ../bluexp-dataset/dw/dw-x-doc.json
# Generated key for ../bluexp-dataset/cm/wf_gcp_ontap_create_cifs.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_ontap_create_vol_nfs.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_cloud_md_create_account.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_ontap_get_volumes.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_identity_get_accounts.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_ontap_add_disks_aggr.adoc
# Generated key for ../bluexp-dataset/cm/wf_onprem_ontap_create_vol_cifs.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_get_zones.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_cloud_create_we_paygo.adoc
# Generated key for ../bluexp-dataset/cm/wf_onprem_ontap_get_aggrs.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_ontap_delete_cifs.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_ontap_create_quote.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_snapshot_policies.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_cloud_md_get_vnets.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_ontap_create_vol_nfs.adoc
# Generated key for ../bluexp-dataset/cm/api_ref_resources.adoc
# Generated key for ../bluexp-dataset/cm/wf_onprem_ontap_modify_volume.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_get_service_accounts.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_ontap_delete_aggr.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_ontap_get_cifs.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_ontap_add_disks_aggr.adoc
# Generated key for ../bluexp-dataset/cm/sidebar.yml
# Generated key for ../bluexp-dataset/cm/cvo_deployment.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_cloud_md_get_regions.adoc
# Generated key for ../bluexp-dataset/cm/wf_onprem_ontap_create_vol_iscsi.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_identity_create_nss_key.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_cloud_md_get_permutations.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_cloud_md_get_route_tables.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_ontap_repl_create_repl.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_identity_get_supported_srv.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_ontap_get_aggrs.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_occm_attach_subscription.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_ontap_get_igroups.adoc
# Generated key for ../bluexp-dataset/cm/wf_onprem_flexgroup_ontap_create_vol.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_ontap_create_aggr.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_ontap_modify_volume.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_ontap_repl_get_ic_lifs.adoc
# Generated key for ../bluexp-dataset/cm/wf_onprem_get_wes.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_ontap_repl_update_repl.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_identity_get_tenants.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_ontap_modify_volume.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_ontap_repl_get_rel_we_status.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_cloud_get_wes.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_ontap_get_aggrs.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_cloud_create_we_paygo.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_ontap_delete_volume.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_ontap_get_cifs.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_ontap_create_aggr.adoc
# Generated key for ../bluexp-dataset/cm/wf_onprem_ontap_get_volumes.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_create_we_byol.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_ontap_get_igroups.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_ontap_create_vol_iscsi.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_ontap_create_vol_iscsi.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_identity_get_provider_accounts.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_ontap_create_cifs.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_get_supported_features.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_ontap_repl_get_rel_status.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_ontap_get_volumes.adoc
# Generated key for ../bluexp-dataset/cm/security.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_ontap_get_cifs.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_cloud_md_get_availability_zones.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_ontap_get_aggrs.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_get_instance_type_nosupport.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_create_buckets.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_cloud_md_get_ebs_vol_types.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_identity_get_nss_key.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_ontap_create_quote.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_get_supported_tiers.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_create_we_paygo.adoc
# Generated key for ../bluexp-dataset/cm/wf_onprem_discover_wes.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_ontap_repl_get_we_schedules.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_cloud_create_we_capacity.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_cloud_create_we_byol.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_get_buckets.adoc
# Generated key for ../bluexp-dataset/cm/your_api_call.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_ontap_md_get_snapmirror_policies.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_cloud_get_wes.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_ontap_create_quote.adoc
# Generated key for ../bluexp-dataset/cm/overview.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_ontap_modify_volume.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_ontap_delete_cifs.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_ontap_create_vol_cifs.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_cloud_add_capacity.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_delete_we.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_cloud_md_get_key_pairs.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_get_vpcs.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_cloud_md_get_permutations.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_get_disk_types.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_ontap_delete_volume.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_ontap_get_volumes.adoc
# Generated key for ../bluexp-dataset/cm/wf_onprem_ontap_create_vol_nfs.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_ontap_delete_volume.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_cloud_md_get_packages.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_get_permutations.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_identity_get_saas_mp.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_identity_delete_nss_key.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_ontap_repl_get_sm_rels.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_ontap_get_igroups.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_get_wes.adoc
# Generated key for ../bluexp-dataset/cm/api_ref_definitions.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_cloud_create_we_byol.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_cloud_md_get_storage_account_types.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_cloud_delete_we.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_ontap_delete_aggr.adoc
# Generated key for ../bluexp-dataset/cm/prepare.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_ontap_create_vol_iscsi.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_get_network_requirements.adoc
# Generated key for ../bluexp-dataset/cm/wf_onprem_ontap_get_cifs.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_get_tag_keys.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_get_projects.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_occm_get_task.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_ontap_add_disks_aggr.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_ontap_create_aggr.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_ontap_create_vol_cifs.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_ontap_create_vol_nfs.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_cloud_create_we_capacity.adoc
# Generated key for ../bluexp-dataset/cm/api_reference.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_ontap_delete_aggr.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_create_we_capacity.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_cloud_delete_we.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_cloud_md_get_packages.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_ontap_repl_delete_repl.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_get_encryption_keys.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_get_regions.adoc
# Generated key for ../bluexp-dataset/cm/wf_onprem_before.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_ontap_create_vol_cifs.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_cloud_md_create_account.adoc
# Generated key for ../bluexp-dataset/cm/workflow_processes.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_before.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_identity_get_nss_keys.adoc
# Generated key for ../bluexp-dataset/cm/wf_cvo_before.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_ontap_delete_cifs.adoc
# Generated key for ../bluexp-dataset/cm/wf_azuregcp_ontap_create_aggr.adoc
# Generated key for ../bluexp-dataset/cm/wf_common_ontap_md_get_snapmirror_svm_policies.adoc
# Generated key for ../bluexp-dataset/cm/wf_gcp_cloud_md_get_packages.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_ontap_create_cifs.adoc
# Generated key for ../bluexp-dataset/cm/wf_aws_cloud_md_get_vpcs.adoc
# Generated key for ../bluexp-dataset/cm/wf_azure_cloud_md_get_regions.adoc
# Generated key for ../bluexp-dataset/cm/wf_onprem_ontap_delete_volume.adoc
#
# ✅ Processed 193 files → ./uuid_file_map.csv
