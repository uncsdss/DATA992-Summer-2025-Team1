# %%
import networkx as nx
import os
import json
import yaml
from llama_index.core import Document
from llama_index.core import Settings, VectorStoreIndex
from llama_index.core.node_parser import SentenceSplitter
from llama_index.embeddings.openai import OpenAIEmbedding

# %%
repo_path = "../../data/bluexp-dataset"

EXT_HANDLERS = {
    "json": lambda p: json.dumps(json.load(open(p, encoding="utf-8")), indent=2),
    "yaml": lambda p: yaml.safe_dump(yaml.safe_load(open(p, encoding="utf-8")), sort_keys=False),
    "yml" : lambda p: yaml.safe_dump(yaml.safe_load(open(p, encoding="utf-8")), sort_keys=False),
    "adoc": lambda p: open(p, encoding="utf-8").read(),
}

docs = []
for dirpath, _, filenames in os.walk(repo_path):
    for fname in filenames:
        ext = fname.rsplit(".", 1)[-1].lower()
        if ext in EXT_HANDLERS:
            full_path = os.path.join(dirpath, fname)
            try:
                text = EXT_HANDLERS[ext](full_path)
            except Exception as e:
                print(f"⚠️ failed to load {full_path}: {e}")
                continue
            docs.append(Document(text=text, metadata={"source": full_path}))

print(f"✅ Loaded {len(docs)} documents from {repo_path}")
# Out:
# ✅ Loaded 193 documents from ../bluexp-dataset

# %%
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path='.env')
print("Loaded OPENAI_API_KEY:", os.getenv("OPENAI_API_KEY") is not None)
# Out:
# Loaded OPENAI_API_KEY: True

# %%
# Chunking config
Settings.chunk_size = 1000
Settings.chunk_overlap = 200
splitter = SentenceSplitter(chunk_size=Settings.chunk_size,
                            chunk_overlap=Settings.chunk_overlap)
Settings.text_splitter = splitter

# Build & embed
index = VectorStoreIndex.from_documents(
    documents=docs,
    embed_model=OpenAIEmbedding(model="text-embedding-3-small"),
    show_progress=True
)

storage_ctx = index._storage_context
docstore    = storage_ctx.docstore

ref_info = docstore.get_all_ref_doc_info()  

all_nodes = docstore.docs

# Preview for the first few chunks of each file
for src, info in ref_info.items():
    print(f"📄 Source file: {src}")
    for node_id in info.node_ids[:3]:
        node = all_nodes[node_id]
        print("  • chunk_id  :", node_id)
        print("    metadata  :", node.metadata)
        print("    preview   :", node.get_content()[:100].replace("\n", " "))
    print("-" * 40)
# Out:
# Parsing nodes:   0%|          | 0/193 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/1053 [00:00<?, ?it/s]
# 📄 Source file: 00b595d8-b58d-4774-a0aa-ecc29ebba350
#   • chunk_id  : 56608a54-47d1-4215-aa5b-d556b2db0cd3
#     metadata  : {'source': '../bluexp-dataset/_index.yml'}
#     preview   : indexpage:   title: BlueXP API documentation   lead: BlueXP enables you to build, protect, and gover
# ----------------------------------------
# 📄 Source file: f66fc940-e7c7-4ddd-9931-3b324003aa12
#   • chunk_id  : 2d1e8925-2cfd-4779-922a-8ea77c163b04
#     metadata  : {'source': '../bluexp-dataset/project.yml'}
#     preview   : settings:   name: API   harmony_integration: maestro   platform: cloud   internal:     pdf_enabled:
# ----------------------------------------
# 📄 Source file: a7790d42-c4b2-4bb6-b8d0-c8578c217a27
#   • chunk_id  : 84ba6cfc-b5f8-4bd4-87b2-8b56453e7dea
#     metadata  : {'source': '../bluexp-dataset/legal-notices.adoc'}
#     preview   : --- sidebar: sidebar permalink: legal-notices.html keywords: copyrights, notice, trademarks, patents
# ----------------------------------------
# 📄 Source file: a2469dd2-fa39-4029-a761-8d8399a3ab8a
#   • chunk_id  : 52ca9a3f-e706-45f3-a3ff-24ece6f1f34d
#     metadata  : {'source': '../bluexp-dataset/api-cm/sidebar.yml'}
#     preview   : section: api-cm title: ONTAP management entries: - title: Get started   entries:   - title: Overview
#   • chunk_id  : 2a2e6e95-f9a5-4d68-ba79-5aaf0ae4fbee
#     metadata  : {'source': '../bluexp-dataset/api-cm/sidebar.yml'}
#     preview   : html     - title: Metadata       entries:       - title: Get regions         url: /cm/wf_aws_cloud_m
#   • chunk_id  : 3bc28f2b-bf00-4a5e-8995-1f14b013a831
#     metadata  : {'source': '../bluexp-dataset/api-cm/sidebar.yml'}
#     preview   : html       - title: Get iGroups         url: /cm/wf_azure_ontap_get_igroups.html     - title: Metada
# ----------------------------------------
# 📄 Source file: 0cac0650-ebae-42c5-9377-bf972bef1cc8
#   • chunk_id  : 5868b2df-4593-44ed-bbf7-44a782afe86a
#     metadata  : {'source': '../bluexp-dataset/credential/sidebar.yml'}
#     preview   : section: credential title: Credentials generate: credential
# ----------------------------------------
# 📄 Source file: 27c98fd6-6f60-47cf-ab5a-3f5bd12e7620
#   • chunk_id  : 689babc5-d06a-4357-89d0-cdcc772f6e0e
#     metadata  : {'source': '../bluexp-dataset/credential/credential.json'}
#     preview   : {   "openapi": "3.0.0",   "info": {     "title": "Credentials service API",     "description": "  <d
#   • chunk_id  : 669dcf74-4b0e-4536-8704-120eda2cd0b8
#     metadata  : {'source': '../bluexp-dataset/credential/credential.json'}
#     preview   : See <a href=\"https://docs.netapp.com/us-en/bluexp-automation/platform/http_details.html#response-he
#   • chunk_id  : d19b0e15-d948-42b7-beaa-eaa4256f4378
#     metadata  : {'source': '../bluexp-dataset/credential/credential.json'}
#     preview   : \n<p>You can perform the following actions with the Azure endpoints:</p>\n<ul>\n<li>Create service p
# ----------------------------------------
# 📄 Source file: 39b4d1bd-2565-4c6b-93fb-44ed3b870b59
#   • chunk_id  : 76a28d12-5837-4490-90ac-3f1b76e791cd
#     metadata  : {'source': '../bluexp-dataset/credential/credential-x-doc.json'}
#     preview   : {   "paths": {     "/health": {       "get": {         "x-doc": {           "title": "",           "
# ----------------------------------------
# 📄 Source file: 170f0a8e-2382-48fe-9bc3-1afc63dc50d1
#   • chunk_id  : 0ec7fae2-e13c-4218-a135-4a4bb5fbf56e
#     metadata  : {'source': '../bluexp-dataset/cbs/sidebar.yml'}
#     preview   : section: cbs title: Backup and recovery generate: cbs
# ----------------------------------------
# 📄 Source file: 92d7d5b5-a6f7-43e8-ad25-234222642989
#   • chunk_id  : 524902ff-adad-42d3-a113-9f4fe34c5d69
#     metadata  : {'source': '../bluexp-dataset/cbs/cbs-x-doc.json'}
#     preview   : {   "paths": {     "/account/{accountId}/providers/cloudmanager_cbs/api/v1/sfr/volume/{volumeId}/fil
#   • chunk_id  : 53ffa695-4943-4cde-ac76-aa572a7cd016
#     metadata  : {'source': '../bluexp-dataset/cbs/cbs-x-doc.json'}
#     preview   : html",           "explorer": false         }       }     },     "/account/{accountId}/providers/clou
#   • chunk_id  : c8776f0b-4b3d-49ad-8ddf-69da878b5946
#     metadata  : {'source': '../bluexp-dataset/cbs/cbs-x-doc.json'}
#     preview   : "get": {         "x-doc": {           "title": "Retrieve volume information",           "category":
# ----------------------------------------
# 📄 Source file: 0cde890e-dd60-4806-8029-4df72f979d86
#   • chunk_id  : c8860b57-dbb7-43d3-8346-611a60e00016
#     metadata  : {'source': '../bluexp-dataset/cbs/cbs.json'}
#     preview   : {   "swagger": "2.0",   "info": {     "title": "BlueXP backup and recovery REST API Reference",
#   • chunk_id  : 221c8e88-6522-4382-81bc-ebb9c9e1fe43
#     metadata  : {'source': '../bluexp-dataset/cbs/cbs.json'}
#     preview   : <tbody><tr><td>license</td><td>accountId(required),</br>workingEnvironmentId.</br>    <tbody><tr><td
#   • chunk_id  : e9ea1a18-d09c-4ff1-868a-c1a66a2cb2eb
#     metadata  : {'source': '../bluexp-dataset/cbs/cbs.json'}
#     preview   : It enables you to perform a quick and focused search for files across all the backups in the cloud a
# ----------------------------------------
# 📄 Source file: 3cee9fbe-56f8-4620-b8ab-43bc7cf51e29
#   • chunk_id  : 859c1fa1-d30b-4304-b76a-c5c55ac5c552
#     metadata  : {'source': '../bluexp-dataset/ipa/sidebar.yml'}
#     preview   : section: ipa title: IPA generate: ipa
# ----------------------------------------
# 📄 Source file: 6a069769-56b4-4e09-a3e7-99d138013bf6
#   • chunk_id  : 6722de73-55ff-46a6-9dfc-901f5a138aef
#     metadata  : {'source': '../bluexp-dataset/ipa/ipa-x-doc.json'}
#     preview   : {   "paths": {     "/ipa/account/{accountId}/serial-number/{serialNumber}/register": {       "post":
#   • chunk_id  : a7a285f8-fd9f-4355-812b-b2a41b45c425
#     metadata  : {'source': '../bluexp-dataset/ipa/ipa-x-doc.json'}
#     preview   : "delete": {         "x-doc": {           "title": "Delete NSS key credentials",           "category"
#   • chunk_id  : 39f23ebb-712c-45de-a89a-91c69772a6b7
#     metadata  : {'source': '../bluexp-dataset/ipa/ipa-x-doc.json'}
#     preview   : "category": "NSS",           "filename": "get-ipa-accounts-nss-data.html",           "subcategory":
# ----------------------------------------
# 📄 Source file: 0c8afc38-f24f-498f-ba37-1a2f6f47d5c7
#   • chunk_id  : 1609f594-8b81-4112-967f-db50e964e53d
#     metadata  : {'source': '../bluexp-dataset/ipa/ipa.json'}
#     preview   : {   "openapi": "3.0.3",   "info": {     "title": "IPA service REST API reference",     "description"
#   • chunk_id  : c5d16002-24b0-4630-8ca5-e93214a6f34f
#     metadata  : {'source': '../bluexp-dataset/ipa/ipa.json'}
#     preview   : Contains the JWT token (user/service)</td>\n</tr>\n<tr>\n<td><code>X-service-request-id</code></td>\
#   • chunk_id  : 94fd972c-10d0-4f7f-bfc1-744f35a2d2c0
#     metadata  : {'source': '../bluexp-dataset/ipa/ipa.json'}
#     preview   : }     },     "schemas": {       "def-0": {         "title": "Authorization",         "type": "object
# ----------------------------------------
# 📄 Source file: 411cd953-456c-453c-985c-ecf49891fe05
#   • chunk_id  : a01ed00f-1a17-4659-a8bf-aa10c378494f
#     metadata  : {'source': '../bluexp-dataset/tenancy/sidebar.yml'}
#     preview   : section: tenancy title: Accounts (tenancy) generate: tenancy
# ----------------------------------------
# 📄 Source file: 831dd256-14c3-4560-a20c-fe591e21f236
#   • chunk_id  : a57c3d02-f9c5-4cb6-a177-315d60fb5676
#     metadata  : {'source': '../bluexp-dataset/tenancy/tenancy-x-doc.json'}
#     preview   : {   "paths": {     "/tenancy/account/{accountName}": {       "post": {         "x-doc": {
#   • chunk_id  : 63373801-233f-4bd7-b70d-b1b8a466fe54
#     metadata  : {'source': '../bluexp-dataset/tenancy/tenancy-x-doc.json'}
#     preview   : "category": "Account",           "filename": "get-tenancy-account.html",           "subcategory": nu
#   • chunk_id  : 39d0f6a0-cffe-46bb-b83e-d57f46159da0
#     metadata  : {'source': '../bluexp-dataset/tenancy/tenancy-x-doc.json'}
#     preview   : html",           "subcategory": null         }       }     },     "/tenancy/authorize-agent-in-accou
# ----------------------------------------
# 📄 Source file: bb9cec10-ba3d-4e9c-950e-57b2367f2498
#   • chunk_id  : 389dba47-9929-4959-a72b-bd34b50a95f5
#     metadata  : {'source': '../bluexp-dataset/tenancy/tenancy.json'}
#     preview   : {   "swagger": "2.0",   "info": {     "title": "Tenancy service REST API reference",     "descriptio
#   • chunk_id  : c9f6a766-bb77-457e-bff1-2cabfebbbf06
#     metadata  : {'source': '../bluexp-dataset/tenancy/tenancy.json'}
#     preview   : See <a href=\"https://docs.netapp.com/us-en/cloud-manager-automation/platform/http_details.html\">RE
#   • chunk_id  : 9377164b-1548-43c6-9524-0f6486ea0e97
#     metadata  : {'source': '../bluexp-dataset/tenancy/tenancy.json'}
#     preview   : The general definition pattern is <code>&lt;principal_type&gt;:&lt;action&gt;</code>. Two examples i
# ----------------------------------------
# 📄 Source file: a66c2788-043b-49a3-bfe7-debbac15fd67
#   • chunk_id  : 9579815f-342e-4d29-bec1-52c59913e264
#     metadata  : {'source': '../bluexp-dataset/platform/aa_concepts.adoc'}
#     preview   : --- sidebar: sidebar permalink: platform/aa_concepts.html keywords: bluexp, authorization, authentic
# ----------------------------------------
# 📄 Source file: 9abe41e0-ae40-4137-923f-cf5095c65341
#   • chunk_id  : 7094993e-90cd-485d-82f1-6160afe0ceb4
#     metadata  : {'source': '../bluexp-dataset/platform/create_user_token.adoc'}
#     preview   : --- sidebar: sidebar permalink: platform/create_user_token.html keywords: generate, user, token, blu
#   • chunk_id  : 40b4db3a-af9c-4ecf-900c-f86b6b032a82
#     metadata  : {'source': '../bluexp-dataset/platform/create_user_token.adoc'}
#     preview   : [cols="25,75"*,options="header"] |=== |HTTP method |Resource path |POST |/oauth/token |===  curl exa
# ----------------------------------------
# 📄 Source file: ebf847d2-a46b-45d0-93d5-b8c7377fe0cf
#   • chunk_id  : fb6b5203-f228-4f85-b41e-6c8789a00ac8
#     metadata  : {'source': '../bluexp-dataset/platform/http_details.adoc'}
#     preview   : --- sidebar: sidebar permalink: platform/http_details.html keywords: http, details, bluexp, rest, ap
# ----------------------------------------
# 📄 Source file: 36ef2d70-7c7d-4753-8dae-8f3c1d80f402
#   • chunk_id  : 19966673-e396-4a5d-b2a7-5515a37d1541
#     metadata  : {'source': '../bluexp-dataset/platform/get_identifiers.adoc'}
#     preview   : --- sidebar: sidebar permalink: platform/get_identifiers.html keywords: client, id, account, identif
# ----------------------------------------
# 📄 Source file: 5a8d68af-41a5-44c8-9d4d-4d019210e1bb
#   • chunk_id  : 6dbb81cf-ed3d-486c-89c2-f24c0c77ccf5
#     metadata  : {'source': '../bluexp-dataset/platform/sidebar.yml'}
#     preview   : section: platform title: Get started entries: - title: BlueXP control plane   url: /platform/overvie
# ----------------------------------------
# 📄 Source file: e5131309-3d4d-458e-bc2d-d66c74dd6f40
#   • chunk_id  : c3063430-4243-4c47-a8c8-ae92d28fec09
#     metadata  : {'source': '../bluexp-dataset/platform/workflows_tasks.adoc'}
#     preview   : --- sidebar: sidebar permalink: platform/workflows_tasks.html keywords: workflows, processes, bluexp
# ----------------------------------------
# 📄 Source file: 08427d45-17ad-4574-ac9e-f450a0b56e5a
#   • chunk_id  : f7efd47f-8623-417c-80c4-113cd8670d79
#     metadata  : {'source': '../bluexp-dataset/platform/user_access_tokens.adoc'}
#     preview   : --- sidebar: sidebar permalink: platform/user_access_tokens.html keywords: bluexp, rest, apis, acces
#   • chunk_id  : 8c6613e2-9486-4928-85d0-d205a1e02ba0
#     metadata  : {'source': '../bluexp-dataset/platform/user_access_tokens.adoc'}
#     preview   : Users who sign in using a non-federated user account can obtain either a long-lived refresh token or
#   • chunk_id  : 35986d96-1bb0-4e27-b62d-2ba91e4d4def
#     metadata  : {'source': '../bluexp-dataset/platform/user_access_tokens.adoc'}
#     preview   : mwavS7rJYUwMrnu0CL_8J3N-WJG2_UwdD3bplxAR-p6m8_2vZH8o4SjJAvaL3JwvQqcVHoh7YfyWd5TH SKQAJawGyTQnqdOdp_2
# ----------------------------------------
# 📄 Source file: 13735feb-774a-453e-b35b-f4f8ea16f347
#   • chunk_id  : d898e7d6-8b04-4b75-8985-d010760b144d
#     metadata  : {'source': '../bluexp-dataset/platform/concepts.adoc'}
#     preview   : --- sidebar: sidebar permalink: platform/concepts.html keywords: rest, api, cloud, manager, http, en
# ----------------------------------------
# 📄 Source file: 9de5ce50-c34f-4ca3-948b-67aa3c9b3ea9
#   • chunk_id  : 92937858-d4e5-4b25-9b51-ef9c55bba1c0
#     metadata  : {'source': '../bluexp-dataset/platform/overview.adoc'}
#     preview   : --- sidebar: sidebar permalink: platform/overview.html keywords: overview, bluexp, rest, apis, hybri
# ----------------------------------------
# 📄 Source file: 3ed4f24f-15f9-46ee-bb38-7b3b1a622f46
#   • chunk_id  : c2c34475-1ddb-4abd-8625-2eb19c634415
#     metadata  : {'source': '../bluexp-dataset/platform/register_service.adoc'}
#     preview   : --- sidebar: sidebar permalink: platform/register_service.html keywords: generate, user, token, blue
# ----------------------------------------
# 📄 Source file: 70d91bfe-a053-40e3-92a8-5c158e4edaa8
#   • chunk_id  : 16b6c774-0229-4c74-b44a-58a10860d1a5
#     metadata  : {'source': '../bluexp-dataset/platform/api_explorer.adoc'}
#     preview   : --- sidebar: sidebar permalink: platform/api_explorer.html keywords: generate, user, token, api expl
# ----------------------------------------
# 📄 Source file: 3a0ea1b6-7cea-4239-a1d6-6ad34afa75ea
#   • chunk_id  : f55ad66e-3a61-4a0c-beac-4c109e82368f
#     metadata  : {'source': '../bluexp-dataset/platform/get_nss_key.adoc'}
#     preview   : --- sidebar: sidebar permalink: platform/get_nss_key.html keywords: nss, credentials, key, bluexp, r
# ----------------------------------------
# 📄 Source file: 1dea2793-1407-483e-94c6-7c2f23c9410e
#   • chunk_id  : 9b105577-77bd-474d-ab55-11132d45dc6e
#     metadata  : {'source': '../bluexp-dataset/platform/create_service_token.adoc'}
#     preview   : --- sidebar: sidebar permalink: platform/create_service_token.html keywords: generate, user, token,
# ----------------------------------------
# 📄 Source file: 61dcb995-9809-4ffd-b743-b67d156f6fb3
#   • chunk_id  : 7a93a088-972c-4acc-a1de-561cf03a9abd
#     metadata  : {'source': '../bluexp-dataset/platform/additional_considerations.adoc'}
#     preview   : --- sidebar: sidebar permalink: platform/additional_considerations.html keywords: bluexp, rest, api,
# ----------------------------------------
# 📄 Source file: 7a1107fd-d4f3-4904-af71-a1a95f4396b6
#   • chunk_id  : 710ccfc0-ceec-4bfd-8f05-364ec9928ee7
#     metadata  : {'source': '../bluexp-dataset/platform/use_rest_apis.adoc'}
#     preview   : --- sidebar: sidebar permalink: platform/use_rest_apis.html keywords: bluexp, rest, apis, authentica
# ----------------------------------------
# 📄 Source file: b0129826-4a4e-4f48-a64e-266444fcc733
#   • chunk_id  : b581fb79-72b7-4376-8285-a72461c7b06f
#     metadata  : {'source': '../bluexp-dataset/platform/connectors_clients.adoc'}
#     preview   : --- sidebar: sidebar permalink: platform/connectors_clients.html keywords: connector, bluexp, rest,
# ----------------------------------------
# 📄 Source file: 08325494-6e0e-418c-b754-210bde0476e3
#   • chunk_id  : a937af86-4ff9-4c3d-830b-185b6230b497
#     metadata  : {'source': '../bluexp-dataset/platform/grant_types.adoc'}
#     preview   : --- sidebar: sidebar permalink: platform/grant_types.html keywords: oauth2, refresh token, password
# ----------------------------------------
# 📄 Source file: c3edbd49-5e9d-47fe-9a64-856528ac11d8
#   • chunk_id  : 7fb4642d-6e73-4552-9a8f-20bd0cf8197d
#     metadata  : {'source': '../bluexp-dataset/workflows/sidebar.yml'}
#     preview   : section: workflows title: BlueXP common workflows and tasks entries: - title: Get required identifie
# ----------------------------------------
# 📄 Source file: 5479e058-92e8-450e-a828-2b779885e456
#   • chunk_id  : d86713b2-2b6a-45c9-8239-85db9c7990dc
#     metadata  : {'source': '../bluexp-dataset/copysync/sidebar.yml'}
#     preview   : section: copysync title: Copy and sync generate: copysync
# ----------------------------------------
# 📄 Source file: 40d6132f-3c60-4fcc-8fa8-9ad9f0b20d55
#   • chunk_id  : db821174-192d-43f6-b49d-3daa2f538cf7
#     metadata  : {'source': '../bluexp-dataset/copysync/copysync-x-doc.json'}
#     preview   : {   "paths": {     "/api/accounts": {       "get": {         "x-doc": {           "title": "Retrieve
#   • chunk_id  : 8b10a2a3-eff4-450b-aef7-b29dd0ee3cd0
#     metadata  : {'source': '../bluexp-dataset/copysync/copysync-x-doc.json'}
#     preview   : "category": "Accounts",           "filename": "delete-api-accounts-licenses-v2-.html",           "su
#   • chunk_id  : 7dc3231a-bc52-4492-ad17-306d963143a7
#     metadata  : {'source': '../bluexp-dataset/copysync/copysync-x-doc.json'}
#     preview   : html",           "subcategory": null,           "explorer": false         }       }     },     "/api
# ----------------------------------------
# 📄 Source file: 7fb763fd-4227-444e-ad5f-c25085c5be92
#   • chunk_id  : 49884767-e82d-42cc-a7c1-92718aa9ab25
#     metadata  : {'source': '../bluexp-dataset/copysync/copysync.json'}
#     preview   : {   "openapi": "3.0.3",   "info": {     "title": "BlueXP Copy and sync API documentation",     "desc
#   • chunk_id  : 17044357-215d-4853-8bbb-41dcee0442bb
#     metadata  : {'source': '../bluexp-dataset/copysync/copysync.json'}
#     preview   : Contains a JWT token (user)</td>\n</tr>\n<tr>\n<td><code>x-account-id</code></td>\n<td>Contains the
#   • chunk_id  : a81fd248-03cb-458d-b9ee-655e03f91ea7
#     metadata  : {'source': '../bluexp-dataset/copysync/copysync.json'}
#     preview   : This is a summary by component, however not every query parameter can be used with each endpoint in
# ----------------------------------------
# 📄 Source file: 63a39c1a-76b9-48e0-8e25-53af0e3f2157
#   • chunk_id  : 418e1853-6012-42d5-9e43-1f7d58381ba7
#     metadata  : {'source': '../bluexp-dataset/fsx/sidebar.yml'}
#     preview   : section: fsx title: Amazon FSx for NetApp ONTAP generate: fsx
# ----------------------------------------
# 📄 Source file: bc0f425e-fb8d-437b-9048-5ec1211b4b16
#   • chunk_id  : 23c1741c-df19-4aa2-9496-ab07c12444ad
#     metadata  : {'source': '../bluexp-dataset/fsx/fsx.json'}
#     preview   : {   "openapi": "3.0.0",   "info": {     "title": "Fsx for Ontap service API",     "description": "
#   • chunk_id  : ee417ed9-3235-4310-8e45-f2e311d2612c
#     metadata  : {'source': '../bluexp-dataset/fsx/fsx.json'}
#     preview   : See <a href=\"https://docs.netapp.com/us-en/cloud-manager-automation/platform/rest_implementation.ht
#   • chunk_id  : 86700a5a-d8f4-4e2b-897c-56090f18b33e
#     metadata  : {'source': '../bluexp-dataset/fsx/fsx.json'}
#     preview   : {       "name": "AWS Operations",       "description": "<details>\n<summary>Overview</summary>\n<fie
# ----------------------------------------
# 📄 Source file: 7ec60e8a-097c-4541-bc3f-b7fbd939aa8a
#   • chunk_id  : e914b79f-0002-4288-8f7e-e102b436f817
#     metadata  : {'source': '../bluexp-dataset/fsx/fsx-x-doc.json'}
#     preview   : {   "paths": {     "/aws-credentials/{accountId}": {       "get": {         "x-doc": {           "ti
#   • chunk_id  : 0ad10965-af7c-4761-9325-e1f76022dc4f
#     metadata  : {'source': '../bluexp-dataset/fsx/fsx-x-doc.json'}
#     preview   : "category": "Working Environments",           "filename": "delete-working-environments--workspace-.h
# ----------------------------------------
# 📄 Source file: 3f7ea298-4ceb-4ea1-80d9-5406485b1641
#   • chunk_id  : 077bb7b1-ef9f-4bed-847c-62be1e32491a
#     metadata  : {'source': '../bluexp-dataset/audit/audit.json'}
#     preview   : {   "openapi": "3.0.0",   "info": {     "title": "Audit service API",     "description": "  <details
#   • chunk_id  : a83c75d0-0d92-4f6c-a06f-52ae08a18f32
#     metadata  : {'source': '../bluexp-dataset/audit/audit.json'}
#     preview   : This is a summary by component, however not every query parameter can be used with each endpoint in
#   • chunk_id  : f4014550-9acd-4101-a107-ec90cbfc6d98
#     metadata  : {'source': '../bluexp-dataset/audit/audit.json'}
#     preview   : Unix epoch in milliseconds",             "example": 1676559600           },           "endTime": {
# ----------------------------------------
# 📄 Source file: 4574eec0-53a0-44c9-b4b0-25459548fab7
#   • chunk_id  : 6d60c034-4ec4-4dd1-988f-8669db589684
#     metadata  : {'source': '../bluexp-dataset/audit/sidebar.yml'}
#     preview   : section: audit title: Audit generate: audit
# ----------------------------------------
# 📄 Source file: 1fe7caa8-46d7-47ab-84ac-e6a366f07dab
#   • chunk_id  : 89f3749c-f462-47de-bff6-fbdf612540d9
#     metadata  : {'source': '../bluexp-dataset/audit/audit-x-doc.json'}
#     preview   : {   "paths": {     "/audit/{accountId}": {       "get": {         "x-doc": {           "title": "Ret
# ----------------------------------------
# 📄 Source file: fe394c18-6474-40ea-b34c-b5a31c9e3df9
#   • chunk_id  : c3305930-eb2d-4d99-80b3-43c84f9dfc9b
#     metadata  : {'source': '../bluexp-dataset/support/additional_resources.adoc'}
#     preview   : --- sidebar: sidebar permalink: support/additional_resources.html keywords: netapp, support, cloud,
# ----------------------------------------
# 📄 Source file: ca86e0b0-3aab-45be-b768-7db123bb74b0
#   • chunk_id  : 8f972044-c2f5-4ead-9aee-38c572645a51
#     metadata  : {'source': '../bluexp-dataset/support/sidebar.yml'}
#     preview   : section: support title: Knowledge and support entries: - title: Additional resources   url: /support
# ----------------------------------------
# 📄 Source file: 9b36825c-1f4b-4a39-9cc5-a3e58b3665b6
#   • chunk_id  : 1e1c537f-7ee7-45da-aeab-5e7b3dfb7866
#     metadata  : {'source': '../bluexp-dataset/automate/blogs.adoc'}
#     preview   : --- sidebar: sidebar permalink: automate/blogs.html keywords: terraform, terraform provider, automat
# ----------------------------------------
# 📄 Source file: 614fd4e7-8924-48ac-882c-d6b658c4f5e2
#   • chunk_id  : 7d6d158c-0584-4453-bc42-b505880b4491
#     metadata  : {'source': '../bluexp-dataset/automate/sidebar.yml'}
#     preview   : section: automate title: Automation technologies entries: - title: Overview   url: /automate/overvie
# ----------------------------------------
# 📄 Source file: 06a8f35f-33d4-4e5d-9afd-c47df6b2507c
#   • chunk_id  : 128204cb-e6fe-43f3-92ac-11e42a227a7d
#     metadata  : {'source': '../bluexp-dataset/automate/overview.adoc'}
#     preview   : --- sidebar: sidebar permalink: automate/overview.html keywords: terraform, terraform provider, auto
# ----------------------------------------
# 📄 Source file: 9ff4ec21-e4c4-41af-899b-d4ab472fd3bf
#   • chunk_id  : 9ba428a9-5e8b-4047-96c7-1c1c252e0672
#     metadata  : {'source': '../bluexp-dataset/tenancyv4/tenancyv4.yaml'}
#     preview   : components:   parameters:     continue:       description: 'Indicates the token to resume from when
#   • chunk_id  : 49a5c100-5b36-48b9-9290-a0d13b44d3de
#     metadata  : {'source': '../bluexp-dataset/tenancyv4/tenancyv4.yaml'}
#     preview   : status: '403'             title: Operation not permitted             type: https://bluexp.netapp.io/
#   • chunk_id  : 8ddb13f6-457e-42be-93c0-b81147205b8e
#     metadata  : {'source': '../bluexp-dataset/tenancyv4/tenancyv4.yaml'}
#     preview   : items:             additionalProperties:               type: string             type: object
# ----------------------------------------
# 📄 Source file: 39649c29-6dca-4b03-a06d-1391bea9e67e
#   • chunk_id  : a16db62d-ee4a-4db7-9db4-0f348dc8ed56
#     metadata  : {'source': '../bluexp-dataset/tenancyv4/sidebar.yml'}
#     preview   : section: tenancyv4 title: Identity and access management (IAM) generate: tenancyv4
# ----------------------------------------
# 📄 Source file: a7d7de28-9b41-4487-b840-f5a76d3ea029
#   • chunk_id  : 8adb0c20-b638-470f-b11a-cd30fcda5c6d
#     metadata  : {'source': '../bluexp-dataset/tenancyv4/tenancyv4-x-doc.yml'}
#     preview   : paths:   /bindings:     get:       x-doc:         title: List all bindings         category: Binding
#   • chunk_id  : 797cb6a5-9ec6-41c8-86ae-2718370347ea
#     metadata  : {'source': '../bluexp-dataset/tenancyv4/tenancyv4-x-doc.yml'}
#     preview   : html         subcategory: null         explorer: false     post:       x-doc:         title: Create
#   • chunk_id  : 0faebdee-eec3-4a3f-8292-703921c70a8d
#     metadata  : {'source': '../bluexp-dataset/tenancyv4/tenancyv4-x-doc.yml'}
#     preview   : html         subcategory: null         explorer: false     get:       x-doc:         title: Retrieve
# ----------------------------------------
# 📄 Source file: 6a15815b-64de-42dd-b11d-e3dbcbd838a3
#   • chunk_id  : 33fe8a5a-a12c-40de-919b-42b2b2da2c2f
#     metadata  : {'source': '../bluexp-dataset/dw/dw.json'}
#     preview   : {   "openapi": "3.0.3",   "info": {     "title": "BlueXP digital wallet REST API reference",     "de
#   • chunk_id  : 6d256465-2eca-4ad9-bdb7-537b4492acd9
#     metadata  : {'source': '../bluexp-dataset/dw/dw.json'}
#     preview   : Asynchronous processing and internal process tracking are not supported.</p>\n<p><strong>Note:</stro
#   • chunk_id  : 472cb629-08df-4ab0-82b4-dcca8a08b406
#     metadata  : {'source': '../bluexp-dataset/dw/dw.json'}
#     preview   : <br />\nSee <a href=\"https://docs.netapp.com/us-en/cloud-manager-automation/platform/http_details.h
# ----------------------------------------
# 📄 Source file: 876f963a-519e-4070-9ff0-db5f5dda857b
#   • chunk_id  : 2df33656-1e21-479e-ace9-3252a75d8409
#     metadata  : {'source': '../bluexp-dataset/dw/sidebar.yml'}
#     preview   : section: dw title: Digital wallet generate: dw
# ----------------------------------------
# 📄 Source file: 502c2209-b800-4407-a1c7-0f3a77bb50e8
#   • chunk_id  : c5b89ab8-2e6b-4657-910f-1b76ac9e84fc
#     metadata  : {'source': '../bluexp-dataset/dw/dw-x-doc.json'}
#     preview   : {   "paths": {     "/license/serial-number/{serialNumber}": {       "post": {         "x-doc": {
#   • chunk_id  : 3284fb04-ff6f-45c4-80c1-c9f832375c50
#     metadata  : {'source': '../bluexp-dataset/dw/dw-x-doc.json'}
#     preview   : "category": "External Services",           "filename": "get-license-onprem-account-clusters.html"
# ----------------------------------------
# 📄 Source file: fc57e285-fd4e-4d23-aa9a-cc72ed734e9e
#   • chunk_id  : edfe1238-59d2-4751-ad52-7b757f61297b
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_create_cifs.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_gcp_ontap_create_cifs.html keywords: cloud, manager, rest, api
#   • chunk_id  : b6c054d5-b814-4346-a5e3-36e767624bbd
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_create_cifs.adoc'}
#     preview   : ==== 2. Determine the Active Directory configuration  You need the following configuration parameter
#   • chunk_id  : f197a84c-6530-45aa-af12-4d67dbebbe61
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_create_cifs.adoc'}
#     preview   : === Set up a CIFS server in an Active Directory domain (HA) You can create a CIFS server on the SVM
# ----------------------------------------
# 📄 Source file: 427d7d2d-6b34-4e56-9b23-f690cde4feca
#   • chunk_id  : e8c3d441-dc91-46c8-a6c1-7f2154e7165c
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_ontap_create_vol_nfs.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_azure_ontap_create_vol_nfs.html keywords: cloud, manager, rest
#   • chunk_id  : f518e77a-6302-443c-9ae0-1c2fdb07ceaf
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_ontap_create_vol_nfs.adoc'}
#     preview   : === 1. Select a working environment  Perform the workflow link:wf_azure_cloud_create_we_paygo.html#c
# ----------------------------------------
# 📄 Source file: f9468ec0-cdb0-451f-b2d5-3b96921f1068
#   • chunk_id  : cf5f55ef-9013-4506-bcd6-ae4681be8d3b
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_cloud_md_create_account.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_azure_cloud_md_create_account.html keywords: azure, cloud, pro
# ----------------------------------------
# 📄 Source file: c22bb43c-475b-4e92-8c23-06f379d1009b
#   • chunk_id  : 9b72a5fd-6690-44af-9479-b8876f263f1f
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_get_volumes.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_aws_ontap_get_volumes.html keywords: cloud, manager, rest, api
#   • chunk_id  : 3a054a78-6f99-44db-b0f5-77b2e47486ce
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_get_volumes.adoc'}
#     preview   : [cols="25,25, 25, 45"*,options="header"] |=== |Parameter |Type |Required |Description |`workingEnvir
#   • chunk_id  : ec053ac7-a3d3-4a17-9365-214d9f5600d8
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_get_volumes.adoc'}
#     preview   : === 1. Select the working environment  Perform the workflow link:wf_aws_cloud_get_wes.html#get-worki
# ----------------------------------------
# 📄 Source file: e0a3f9cf-121f-4976-9d58-8cb86268bdf2
#   • chunk_id  : c96afbcb-ba0f-4baf-90d1-b80edc31cae6
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_identity_get_accounts.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_common_identity_get_accounts.html keywords: generate, user, to
# ----------------------------------------
# 📄 Source file: 57a6d5dd-750d-44cd-8dac-4641ac9d459d
#   • chunk_id  : 01c924f0-21b9-43e4-ac4b-3caede39af6f
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_ontap_add_disks_aggr.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_azure_ontap_add_disks_aggr.html keywords: disk, aggregate, clo
# ----------------------------------------
# 📄 Source file: dc291384-49b1-4f6d-8c2c-5f31ef7fba65
#   • chunk_id  : d3cd7af4-7d15-4a01-b8b5-c88c13e7f2e3
#     metadata  : {'source': '../bluexp-dataset/cm/wf_onprem_ontap_create_vol_cifs.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_onprem_ontap_create_vol_cifs.html keywords: vcloud, manager, r
# ----------------------------------------
# 📄 Source file: 785adab0-09e2-4311-bedc-8adad87395f0
#   • chunk_id  : 887e9015-19fb-4fe3-8f7a-3913ae7d5cc0
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_cloud_md_get_zones.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_gcp_cloud_md_get_zones.html keywords: permutations, cloud, vol
# ----------------------------------------
# 📄 Source file: 560fdecd-443b-402a-bf2f-7d78cec8f045
#   • chunk_id  : cc5ff9bf-b565-45cf-87e3-d126c1e6797b
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_cloud_create_we_paygo.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_azure_cloud_create_we_paygo.html keywords: paygo, cloud, volum
#   • chunk_id  : 1f7eed52-ff5b-4be2-81a5-adfb1df33117
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_cloud_create_we_paygo.adoc'}
#     preview   : === 4. Select the Azure availability zone  Perform the workflow link:wf_azure_cloud_md_get_availabil
#   • chunk_id  : 4031f529-40f2-4043-b69a-35865b4245ed
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_cloud_create_we_paygo.adoc'}
#     preview   : Input::  The JSON input example includes the minimum list of parameters.  [NOTE] This request uses P
# ----------------------------------------
# 📄 Source file: 3e061bf0-c45f-4758-bc28-64dc7011b796
#   • chunk_id  : aede01e7-0cd7-4217-9452-a1243a6fc14e
#     metadata  : {'source': '../bluexp-dataset/cm/wf_onprem_ontap_get_aggrs.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_onprem_ontap_get_aggrs.html keywords: cloud, manager, rest, ap
# ----------------------------------------
# 📄 Source file: e74ddec9-70c0-41d6-b2f5-3652dee37999
#   • chunk_id  : cd302f4b-aa88-4ca3-98f2-244b9a97d7e8
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_ontap_delete_cifs.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_azure_ontap_delete_cifs.html keywords: cifs, server, configura
# ----------------------------------------
# 📄 Source file: 253f2ddc-015d-44f2-ac8d-4efacfa4da67
#   • chunk_id  : 2e01b484-09f3-4923-b2a7-a7e476e99fac
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_create_quote.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_gcp_ontap_create_quote.html keywords: cloud, manager, rest, ap
#   • chunk_id  : 39648cc8-7906-4ab8-8c50-c5959cba8f84
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_create_quote.adoc'}
#     preview   : === 1. Select the working environment  Perform the workflow link:wf_gcp_cloud_get_wes.html#get-worki
# ----------------------------------------
# 📄 Source file: 1b5d55a2-79d0-4d90-bb64-0118d4eba7f9
#   • chunk_id  : 8a2e4964-0398-4a8f-8428-8bc4ff91a2f2
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_cloud_md_snapshot_policies.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_gcp_cloud_md_snapshot_policies.html keywords: buckets, cloud,
# ----------------------------------------
# 📄 Source file: e340ade6-5bea-48cd-9e07-ed76de97d3ce
#   • chunk_id  : 69944b86-465e-4d30-aacb-60de524c02dc
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_cloud_md_get_vnets.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_azure_cloud_md_get_vnets.html keywords: permutations, cloud, v
#   • chunk_id  : 8833c745-5c63-4a62-9507-a861ce3ade3b
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_cloud_md_get_vnets.adoc'}
#     preview   : .Output  The JSON output example includes the list of Azure  storage account types.  .JSON output ex
#   • chunk_id  : c33ef04c-420a-4615-964c-ec46c292f959
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_cloud_md_get_vnets.adoc'}
#     preview   : == Get Azure VNets for high availability pair You can perform this workflow to retrieve the Azure ne
# ----------------------------------------
# 📄 Source file: 7c3cca8c-333c-459e-96fb-40339bed6a7b
#   • chunk_id  : e7c5da24-a386-4c0f-bd37-8e33c2620e8e
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_create_vol_nfs.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_gcp_ontap_create_vol_nfs.html keywords: cloud, manager, rest,
#   • chunk_id  : a9ce8ec1-5a83-421d-9c43-a630cd7a273d
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_create_vol_nfs.adoc'}
#     preview   : Create the volume  [cols="25,75"*,options="header"] |=== |HTTP method |Path |POST |/occm/api/gcp/vsa
#   • chunk_id  : 13ed9e0c-3344-459d-9cd6-a02ff2951b29
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_create_vol_nfs.adoc'}
#     preview   : [NOTE] If aggregate name does not exist and the `createAggregateIfNotFound` query parameter is set `
# ----------------------------------------
# 📄 Source file: 08d1badf-82e2-411b-9d48-c65724e99985
#   • chunk_id  : 30580221-05d9-4bd6-b962-f1b8ac24842e
#     metadata  : {'source': '../bluexp-dataset/cm/api_ref_resources.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/api_ref_resources.html keywords: bluexp, rest, apis, accounts, re
#   • chunk_id  : 7e9c43e5-29cb-4736-a47d-456760558adf
#     metadata  : {'source': '../bluexp-dataset/cm/api_ref_resources.adoc'}
#     preview   : CAUTION: This operation is deprecated. ---- PUT /accounts/azure/{cloudProviderAccountId} ----  =====
#   • chunk_id  : d69d840d-dd2f-46e6-931c-cd8556fe68ab
#     metadata  : {'source': '../bluexp-dataset/cm/api_ref_resources.adoc'}
#     preview   : CAUTION: This operation is deprecated. ---- POST /accounts/aws/validate-creds ----  ===== Parameters
# ----------------------------------------
# 📄 Source file: 28ecd46c-742c-4e54-a6f9-d01eb7474e18
#   • chunk_id  : 52a4d2e1-7cd7-4e05-9c67-0cb70989c88b
#     metadata  : {'source': '../bluexp-dataset/cm/wf_onprem_ontap_modify_volume.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_onprem_ontap_modify_volume.html keywords: cloud, manager, rest
# ----------------------------------------
# 📄 Source file: ca72a763-816f-4432-b774-ef6416e3874e
#   • chunk_id  : d56a815e-f9ea-4eef-adcc-fe4b65d4d853
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_cloud_md_get_service_accounts.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_gcp_cloud_md_get_service_accounts.html keywords: cloud, volume
# ----------------------------------------
# 📄 Source file: 9450110b-cbd2-4bed-a013-9494a305d50f
#   • chunk_id  : 6b82bdcb-4b2a-413b-91ed-4fe8d7e7e5c3
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_ontap_delete_aggr.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_azure_ontap_delete_aggr.html keywords: aggregate, delete, work
#   • chunk_id  : 58b4a17a-ee31-4b58-8ebc-423a4fd96ef0
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_ontap_delete_aggr.adoc'}
#     preview   : Path parameters: * <WORKING_ENV_ID> (`workingEnvironmentId`) string * <AGGR_NAME> (`aggregateName`)
# ----------------------------------------
# 📄 Source file: 055f59be-62b6-46c2-a7f1-52865b75ab27
#   • chunk_id  : 745912ea-538f-439c-a865-af3e8f35a98c
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_get_cifs.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_aws_ontap_get_cifs.html keywords: cloud, manager, rest, api su
#   • chunk_id  : b48dd38f-813a-41c4-aa40-82f6738b22e5
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_get_cifs.adoc'}
#     preview   : [cols="25,25, 25, 45"*,options="header"] |=== |Parameter |Type |Required |Description |<SVM_NAME> |Q
# ----------------------------------------
# 📄 Source file: 77ac8788-0882-4aab-a5fa-69c087ea18d5
#   • chunk_id  : 36b623b5-9103-4439-ace0-bf28b255842d
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_add_disks_aggr.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_gcp_ontap_add_disks_aggr.html keywords: disk, aggregate, cloud
# ----------------------------------------
# 📄 Source file: 7053bc9d-a3a5-4160-b19b-5ce4e4725335
#   • chunk_id  : 476bde98-f799-4a63-91f6-d6297454b716
#     metadata  : {'source': '../bluexp-dataset/cm/sidebar.yml'}
#     preview   : section: cm title: API reference url: /cm/api_reference.html entries: - title: Resources   url: /cm/
# ----------------------------------------
# 📄 Source file: b8fd3101-83ae-4c83-a142-0c6dd5e49212
#   • chunk_id  : 31727484-e189-4550-bb69-48fb68e8e1ae
#     metadata  : {'source': '../bluexp-dataset/cm/cvo_deployment.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/cvo_deployment.html keywords: cloud, manager, deployment, rest, a
# ----------------------------------------
# 📄 Source file: 30a1fa5c-1508-4455-bfbf-f062007e3d93
#   • chunk_id  : ea46b91a-fab4-4fec-9ed7-c93a14d9db2c
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_cloud_md_get_regions.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_aws_cloud_md_get_regions.html keywords: cloud, volumes, ontap,
# ----------------------------------------
# 📄 Source file: 377fbab7-6321-4a85-a31c-c95cfb09eeef
#   • chunk_id  : d5347f96-505b-42ca-994a-775e622399ff
#     metadata  : {'source': '../bluexp-dataset/cm/wf_onprem_ontap_create_vol_iscsi.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_onprem_ontap_create_vol_iscsi.html keywords: cloud, manager, r
#   • chunk_id  : fb6f2c6f-a98d-4678-be82-0a714091a768
#     metadata  : {'source': '../bluexp-dataset/cm/wf_onprem_ontap_create_vol_iscsi.adoc'}
#     preview   : === Step 5. Create the volume  You can issue a REST API call to create a volume.  .HTTP method and e
#   • chunk_id  : c9ba0105-662e-4033-be03-37580de44551
#     metadata  : {'source': '../bluexp-dataset/cm/wf_onprem_ontap_create_vol_iscsi.adoc'}
#     preview   : === Step 4. Create the volume  You can issue a REST API call to create a volume.  .HTTP method and e
# ----------------------------------------
# 📄 Source file: 26232d56-4519-45ae-842f-2e505e4aec21
#   • chunk_id  : 6476d1f3-b12e-424b-a9ae-43837688bd79
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_identity_create_nss_key.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_common_identity_create_nss_key.html keywords: bluexp, rest sum
# ----------------------------------------
# 📄 Source file: ea3b35df-3a15-431a-855b-a04085008f50
#   • chunk_id  : 10d1cfbb-cdbb-4e05-a3f4-f59341fd71ec
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_cloud_md_get_permutations.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_aws_cloud_md_get_permutations.html keywords: permutations, clo
#   • chunk_id  : 1abf4e5f-4cb6-4c65-9bea-8fd9eff8f6a3
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_cloud_md_get_permutations.adoc'}
#     preview   : .HTTP method and endpoint  This REST API call uses the following method and endpoint.  [cols="25,75"
# ----------------------------------------
# 📄 Source file: 9c52352a-037c-4cf9-80c1-08ab4223f565
#   • chunk_id  : 18ce2220-4343-4629-85f0-cbb10c1328e5
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_cloud_md_get_route_tables.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_aws_cloud_md_get_route_tables.html keywords: permutations, clo
#   • chunk_id  : c551732c-024b-40e1-90a2-37f067b363b6
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_cloud_md_get_route_tables.adoc'}
#     preview   : .JSON output example  The output includes an array of route tables.  .Example output [%collapsible]
# ----------------------------------------
# 📄 Source file: 38407c58-cf7e-42b7-9400-eba50e690f16
#   • chunk_id  : 9ba9dec8-9409-4aaa-be03-2324fb2b2327
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_ontap_repl_create_repl.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_common_ontap_repl_create_repl.html keywords: bluexp, rest, api
#   • chunk_id  : 1034f463-83b2-499b-9579-81dd6415fd21
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_ontap_repl_create_repl.adoc'}
#     preview   : The JSON input example includes the minimum list of input parameters. The `maxTransferRate` is maxim
# ----------------------------------------
# 📄 Source file: b9747f84-649b-46a6-aa13-3119881e18c9
#   • chunk_id  : c941c4c5-05d1-41d5-a3d2-9815fb1f9c04
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_identity_get_supported_srv.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_common_identity_get_supported_srv.html keywords: cloud, manage
#   • chunk_id  : 3a683bff-fed2-44b1-b45e-af4202ca5d42
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_identity_get_supported_srv.adoc'}
#     preview   : "url": "https://api.bluexp.netapp.com/saas-mp",         "productUrlAzure": "https://portal.azure.com
#   • chunk_id  : 82bb93f4-15d1-4224-9183-e38753e34f5c
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_identity_get_supported_srv.adoc'}
#     preview   : com/cloudmanager_spot/index.html",             "apiUrl": "https://api.bluexp.netapp.com"         },
# ----------------------------------------
# 📄 Source file: 52fae1ea-b154-44e4-a45c-2c7791e95b78
#   • chunk_id  : 0f81f88e-a625-4cfd-a065-80b4e324be55
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_get_aggrs.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_aws_ontap_get_aggrs.html keywords: cloud, manager, rest, api,
#   • chunk_id  : 596f0c7e-894f-4ce6-bd98-4f0db6de4339
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_get_aggrs.adoc'}
#     preview   : "name": "vxx",                  "size": {                     "size": 256,                     "unit
#   • chunk_id  : 890418ed-da10-4f8c-93cd-91c8f25ba91f
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_get_aggrs.adoc'}
#     preview   : "throughput": 250,                 "instance2Id": null              }         ],         "disks": [
# ----------------------------------------
# 📄 Source file: 8c66f6c4-a89d-4bff-a9a3-633b62436649
#   • chunk_id  : 36ff3206-3cb8-4474-8099-7a60a85850ee
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_occm_attach_subscription.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_common_occm_attach_subscription.html keywords: saas, subscript
# ----------------------------------------
# 📄 Source file: a26da968-f058-4f5f-a76a-b04d4d3d2a42
#   • chunk_id  : 986457ac-02c7-45c5-8fbe-c00b9a32f36a
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_get_igroups.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_aws_ontap_get_igroups.html keywords: cloud, manager, rest, api
#   • chunk_id  : c44b374d-deb4-4299-840b-db2d58411d14
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_get_igroups.adoc'}
#     preview   : .Output  The JSON output example includes a list of iGroups.  .JSON output example ---- [     {
# ----------------------------------------
# 📄 Source file: c1727b60-48b8-4ae8-b56c-71472df82e14
#   • chunk_id  : f5da11c7-f461-49a9-a42c-8158df8e0738
#     metadata  : {'source': '../bluexp-dataset/cm/wf_onprem_flexgroup_ontap_create_vol.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_onprem_flexgroup_ontap_create_vol.html keywords: bluexp, rest,
#   • chunk_id  : 37fd7c03-acda-4c0c-8eaf-a898bfcc7c6d
#     metadata  : {'source': '../bluexp-dataset/cm/wf_onprem_flexgroup_ontap_create_vol.adoc'}
#     preview   : .Additional input parameters  The JSON input example includes the minimum list of parameters.  [cols
# ----------------------------------------
# 📄 Source file: 07d1bf4f-59f3-4b3d-bfad-b3c7749a2cb4
#   • chunk_id  : 3502ed16-233a-4b53-87a2-2b653b5cd646
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_create_aggr.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_gcp_ontap_create_aggr.html keywords: cloud, manager, rest, api
# ----------------------------------------
# 📄 Source file: 4e414f95-32fb-4645-bf79-0ae475e2efb6
#   • chunk_id  : 4a96b146-7555-4e30-b777-e587c2b54f19
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_modify_volume.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_gcp_ontap_modify_volume.html keywords: cloud, manager, rest, a
#   • chunk_id  : b0b631db-ccae-42e0-bea2-e73331c1b810
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_modify_volume.adoc'}
#     preview   : [source,json] {  "exportPolicyInfo": {   "policyType": "custom",   "ips": [     "10.XXX.XXX.XXX/24",
# ----------------------------------------
# 📄 Source file: 8ce17b0e-e7ef-4cf3-92b8-fca887494255
#   • chunk_id  : 906e8bb7-92b6-4c31-82a0-e3a6292c1adf
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_ontap_repl_get_ic_lifs.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_common_ontap_repl_get_ic_lifs.html keywords: bluexp, rest, api
# ----------------------------------------
# 📄 Source file: 06798315-7270-4636-a3e4-6ff21aab0854
#   • chunk_id  : 37f7f8e5-6444-4640-9e70-1fe5d2d05fd3
#     metadata  : {'source': '../bluexp-dataset/cm/wf_onprem_get_wes.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_onprem_get_wes.html keywords: cloud, manager, rest, api, list,
# ----------------------------------------
# 📄 Source file: 4eae9cdb-7e59-4b81-8907-24701e71dd90
#   • chunk_id  : 14f87040-1088-497b-ac53-b3df0e4965a9
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_ontap_repl_update_repl.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_common_ontap_repl_update_repl.html keywords: bluexp, rest, api
# ----------------------------------------
# 📄 Source file: a4c6e6f9-7980-4b8a-ae9f-56fa681bda4e
#   • chunk_id  : 77b8101a-d650-4abe-9b88-9b558ca847b4
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_identity_get_tenants.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_common_identity_get_tenants.html keywords: cloud, manager, res
# ----------------------------------------
# 📄 Source file: 2edab744-3fb8-489c-9356-8cf0a829cd6b
#   • chunk_id  : 747dbfb0-99d7-4279-8ea7-f8d11f34275b
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_ontap_modify_volume.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_azure_ontap_modify_volume.html keywords: cloud, manager, rest,
#   • chunk_id  : 9a7939a3-d253-4e31-8f12-aa4f5ef6aa33
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_ontap_modify_volume.adoc'}
#     preview   : [NOTE] ==== The `exportpolicyInfo -> policyType` parameter can have two values `none` and `custom`.
#   • chunk_id  : ade0cecb-1c1b-4f17-a495-0e647a22cc2c
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_ontap_modify_volume.adoc'}
#     preview   : [NOTE] ==== The `exportpolicyInfo -> policyType` parameter can have two values `none` and `custom`.
# ----------------------------------------
# ...
#     preview   : === 1. Get the list of projects  [cols="25,75"*,options="header"] |=== |HTTP method |Path |GET |/occ
# ----------------------------------------
# 📄 Source file: f724e6df-0074-49cc-b35e-b5a2d5399659
#   • chunk_id  : b152f67b-caa5-4ff1-aa31-057ef4f252a1
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_occm_get_task.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_common_occm_get_task.html keywords: http, get, bluexp, rest, a
# ----------------------------------------
# 📄 Source file: 1029b73b-b86b-4e7d-a56b-8f20e12507ee
#   • chunk_id  : 07f66569-1974-42d4-b6e2-7dbfbd83d2ee
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_add_disks_aggr.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_aws_ontap_add_disks_aggr.html keywords: disk, aggregate, cloud
# ----------------------------------------
# 📄 Source file: 79811222-d3a9-4519-9f63-840ce0820145
#   • chunk_id  : 065f329c-437b-4abb-abcc-c9000084cdae
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_ontap_create_aggr.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_azure_ontap_create_aggr.html keywords: cloud, manager, rest, a
#   • chunk_id  : bf381683-7f84-4cf7-a4bb-fc705f15478a
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_ontap_create_aggr.adoc'}
#     preview   : [cols="25,75"*,options="header"] |=== |HTTP method |Path |POST |occm/api/azure/ha/aggregates |===  .
# ----------------------------------------
# 📄 Source file: ee5eb66a-62cd-4d1e-b062-19e86e38778f
#   • chunk_id  : 3f797e3b-76b1-4c3a-936e-e05938a38bca
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_create_vol_cifs.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_aws_ontap_create_vol_cifs.html keywords: vcloud, manager, rest
#   • chunk_id  : b7bcf347-a46a-4f7c-a02d-9ca13881ea14
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_create_vol_cifs.adoc'}
#     preview   : This is a recommended step but is not mandatory.  === Step 6. Create the volume  You can issue the R
#   • chunk_id  : 8417475b-2b03-4696-90cd-4aae644705db
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_create_vol_cifs.adoc'}
#     preview   : === Step 2. Select the working environment  Perform the workflow link:wf_aws_cloud_get_wes.html#get-
# ----------------------------------------
# 📄 Source file: 2826e450-f81b-4668-b997-50db5ed30e7d
#   • chunk_id  : dbedbb70-76c8-4f03-bb01-84dce19b9407
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_create_vol_nfs.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_aws_ontap_create_vol_nfs.html keywords: cloud, manager, rest,
#   • chunk_id  : e136aa53-a83a-4ede-90bd-1ddc596c1f06
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_create_vol_nfs.adoc'}
#     preview   : === Step 5. Select the rules  Choose values for the `exportPolicyInfo->rules->ruleAccessControl` and
#   • chunk_id  : 048ada5e-b533-48eb-9022-66694a447c4c
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_ontap_create_vol_nfs.adoc'}
#     preview   : == Create a volume using NFS for high availability pair You can use this workflow to create volume u
# ----------------------------------------
# 📄 Source file: 19422de8-03f0-498e-a490-a023b32c71f4
#   • chunk_id  : 052bd98f-0a2e-4e3d-9333-b9e094e66023
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_cloud_create_we_capacity.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_aws_cloud_create_we_capacity.html keywords: paygo, cloud, volu
#   • chunk_id  : af58df8c-d9e5-40fd-8ecf-981e6b56a12a
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_cloud_create_we_capacity.adoc'}
#     preview   : === Step 8. (Optional) Obtain an NSS key  An NSS key is *optional* when using a marketplace subscrip
#   • chunk_id  : 8624e8f1-681b-4843-977a-ab1f17e1838b
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_cloud_create_we_capacity.adoc'}
#     preview   : [cols="25,75"*,options="header"] |=== |HTTP method |Path |POST |/occm/api/vsa/working-environments |
# ----------------------------------------
# 📄 Source file: da041ebe-c7aa-480d-951c-049f07e6f5e5
#   • chunk_id  : 357a1315-4917-4022-82a7-b201aaeed767
#     metadata  : {'source': '../bluexp-dataset/cm/api_reference.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/api_reference.html keywords: api, reference, cloud, manager, rest
# ----------------------------------------
# 📄 Source file: 4bcc235d-9bec-4f28-bcf4-0730a982c32a
#   • chunk_id  : c60fa530-738b-4b4d-ab25-a9d6cce624fe
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_delete_aggr.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_gcp_ontap_delete_aggr.html keywords: aggregate, delete, workin
# ----------------------------------------
# 📄 Source file: 5563218b-5bbd-44c3-91a8-122a0512a087
#   • chunk_id  : 23e188bf-852d-4c67-83c3-c06d835b063f
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_cloud_create_we_capacity.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_gcp_cloud_create_we_capacity.html keywords: paygo, cloud, volu
#   • chunk_id  : 94fb84f4-cc3a-4793-b516-a0349e8b3b9d
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_cloud_create_we_capacity.adoc'}
#     preview   : *	Choose the `diskSize` for `gcpVolumeSize` in step 11. *	Choose the `diskType` and `writingSpeedSta
#   • chunk_id  : beb04a86-3527-45ed-9127-7cdeced4c176
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_cloud_create_we_capacity.adoc'}
#     preview   : === 11. Create the working environment  [cols="25,75"*,options="header"] |=== |HTTP method |Path |PO
# ----------------------------------------
# 📄 Source file: c9ffe78e-2e09-42d3-b87a-508c415841b4
#   • chunk_id  : 07ff9f50-38e3-4810-9920-166a5fa9127d
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_cloud_delete_we.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_aws_cloud_delete_we.html keywords: cloud, manager, rest, api,
#   • chunk_id  : b551b66c-3572-4634-a5a5-37569daacd41
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_cloud_delete_we.adoc'}
#     preview   : .JSON output example  None
# ----------------------------------------
# 📄 Source file: 8d702db8-36ed-41c4-af84-058d49112d0b
#   • chunk_id  : 50103373-6585-4ee0-a21a-3f0e96445575
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_cloud_md_get_packages.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_aws_cloud_md_get_packages.html keywords: packages, cloud, volu
#   • chunk_id  : 91291faa-82e3-4614-9987-24ce8dda9f42
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_cloud_md_get_packages.adoc'}
#     preview   : .JSON output example  The JSON output example includes the list of Cloud Volumes ONTAP packages.   -
# ----------------------------------------
# 📄 Source file: ee08890e-b558-4cbe-b2b4-6a21c1024071
#   • chunk_id  : 831d84d0-a739-4bff-980a-acf0f75d0f7c
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_ontap_repl_delete_repl.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_common_ontap_repl_delete_repl.html keywords: bluexp, rest, api
# ----------------------------------------
# 📄 Source file: 7f5c353c-18c6-418f-9aa2-6f0dedbdb7d5
#   • chunk_id  : c836e866-4181-4741-b22c-0a1c75029201
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_cloud_md_get_encryption_keys.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_gcp_cloud_md_get_encryption_keys.html keywords: cloud, volumes
#   • chunk_id  : 051c5891-920d-4123-94c1-f7a3cc3d2615
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_cloud_md_get_encryption_keys.adoc'}
#     preview   : === 3. Get the encryption keys  [cols="25,75"*,options="header"] |=== |HTTP method |Path |GET |/occm
# ----------------------------------------
# 📄 Source file: 2b837b58-dbfa-4844-bbe2-9eeb5b48aa06
#   • chunk_id  : e66c9be9-d16c-4e83-ad79-3a7fe070374b
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_cloud_md_get_regions.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_gcp_cloud_md_get_regions.html keywords: cloud, volumes, ontap,
#   • chunk_id  : 6f950456-bd10-428c-8893-621f92346bce
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_cloud_md_get_regions.adoc'}
#     preview   : Output::  The JSON output provides an example of a list of Google Cloud regions.  JSON output exampl
#   • chunk_id  : f0e9e2ab-372b-4752-9d44-4bd5588dcd5e
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_cloud_md_get_regions.adoc'}
#     preview   : Output::  The JSON output provides an example of a list of Google Cloud regions.  JSON output exampl
# ----------------------------------------
# 📄 Source file: 9fdc777f-393c-42fb-be25-7b2fec405716
#   • chunk_id  : 067da725-03dd-49ee-8744-4f4568c20cd9
#     metadata  : {'source': '../bluexp-dataset/cm/wf_onprem_before.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_onprem_before.html keywords: aws, workflows, cloud, manager, r
# ----------------------------------------
# 📄 Source file: 0f108c7a-337e-4356-bf2c-ba634437846c
#   • chunk_id  : 739aa8f5-ad64-4929-9997-9d32d4fcec04
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_create_vol_cifs.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_gcp_ontap_create_vol_cifs.html keywords: vcloud, manager, rest
#   • chunk_id  : bac71406-cfa1-4fb8-a8c3-476da3fa6264
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_create_vol_cifs.adoc'}
#     preview   : Create the volume  [cols="25,75"*,options="header"] |=== |HTTP method |Path |POST |/occm/api/gcp/vsa
#   • chunk_id  : 0c4bd1e9-27d7-4199-b88d-3e939cf2c9d7
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_create_vol_cifs.adoc'}
#     preview   : === 3. Select the aggregate  Perform the workflow link:wf_gcp_ontap_get_aggrs.html#get-aggregates-fo
# ----------------------------------------
# 📄 Source file: 565ef164-2094-4059-a948-1870f5c9ae65
#   • chunk_id  : aecd76af-f1e5-4bae-bccc-81e5f2a525a1
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_cloud_md_create_account.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_aws_cloud_md_create_account.html keywords: aws, cloud, provide
# ----------------------------------------
# 📄 Source file: e47ae487-ebf7-4a49-8156-75b3f7d577d4
#   • chunk_id  : 48a9bc31-4de2-4740-8b20-acbc73659966
#     metadata  : {'source': '../bluexp-dataset/cm/workflow_processes.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/workflow_processes.html keywords: workflows, processes, bluexp, a
#   • chunk_id  : 8f3868ad-1477-45c8-a2ba-fb7105567e49
#     metadata  : {'source': '../bluexp-dataset/cm/workflow_processes.adoc'}
#     preview   : .Single node and High availability workflows  Many of the workflows vary based on the type of the de
# ----------------------------------------
# 📄 Source file: b11b8012-3736-442d-af42-96abd702002e
#   • chunk_id  : 3593193b-6ae3-46c4-9178-ca979e54e0ae
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_before.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_common_before.html keywords: public, cloud, common, workflow,
# ----------------------------------------
# 📄 Source file: 3489a784-f657-4628-bab2-234d47b780b7
#   • chunk_id  : 64f7e504-6b50-4f18-91df-5be8d54f66ee
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_identity_get_nss_keys.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_common_identity_get_nss_keys.html keywords: bluexp, rest, api
# ----------------------------------------
# 📄 Source file: b3921240-71c0-4b46-9bef-c2f0de8853eb
#   • chunk_id  : 115db47d-5aa0-4267-9d43-eb3814cddfed
#     metadata  : {'source': '../bluexp-dataset/cm/wf_cvo_before.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_cvo_before.html keywords: aws, workflows, cloud, manager, rest
# ----------------------------------------
# 📄 Source file: f12cb42d-fd92-4e3c-870d-e7a7d45f1fcf
#   • chunk_id  : 7c0c82c7-94c0-41a7-a514-4d729e01c861
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_ontap_delete_cifs.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_gcp_ontap_delete_cifs.html keywords: cifs, server, configurati
# ----------------------------------------
# 📄 Source file: 4c8c6f70-9def-49b7-a79f-aaaad30c353b
#   • chunk_id  : 91d31842-83a9-4ce3-9d6c-80fd54ba3750
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azuregcp_ontap_create_aggr.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_azure_ontap_create_aggr.html keywords: cloud, manager, rest, a
# ----------------------------------------
# 📄 Source file: 53130232-d61f-4229-8516-57ed831b5eb2
#   • chunk_id  : 84f2f3b6-9282-436c-a7f8-9c6512f53a39
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_ontap_md_get_snapmirror_svm_policies.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_common_ontap_md_get_snapmirror_svm_policies.html keywords: sna
#   • chunk_id  : 55be16ec-0406-422b-9957-8dbd46190c9e
#     metadata  : {'source': '../bluexp-dataset/cm/wf_common_ontap_md_get_snapmirror_svm_policies.adoc'}
#     preview   : .JSON Output example  The JSON output example includes the list of SnapMirror policies.  .Example ou
# ----------------------------------------
# 📄 Source file: 0c6b9923-3a8f-4d5c-9413-e0ca577cd1ea
#   • chunk_id  : a666306f-ca01-4585-acac-d6cbf3417665
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_cloud_md_get_packages.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_gcp_cloud_md_get_packages.html keywords: permutations, cloud,
#   • chunk_id  : ba102bc3-ded9-4883-a9eb-26930b775cda
#     metadata  : {'source': '../bluexp-dataset/cm/wf_gcp_cloud_md_get_packages.adoc'}
#     preview   : === 1. Get the packages  [cols="25,75"*,options="header"] |=== |HTTP method |Path |GET |/occm/api/gc
# ----------------------------------------
# 📄 Source file: b060829b-6971-44f2-84d1-3571be9af084
#   • chunk_id  : 53bcea7c-ed55-4e67-8c9b-2c78aac782ff
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_ontap_create_cifs.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_azure_ontap_create_cifs.html keywords: cloud, manager, rest, a
#   • chunk_id  : dbfa9df9-b524-433e-bc69-060dd1c7bbd2
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_ontap_create_cifs.adoc'}
#     preview   : ==== 2. Determine the Active Directory configuration  You need the following configuration parameter
#   • chunk_id  : aab04613-7eb7-4f22-8f03-9bd0b927666e
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_ontap_create_cifs.adoc'}
#     preview   : === Set up a CIFS server in an Active Directory domain You can create a CIFS server on the SVM and s
# ----------------------------------------
# 📄 Source file: e447182c-c70b-4d7a-82f1-f3882e6592d7
#   • chunk_id  : eb85423f-59d3-4a88-98db-b7c587b3599f
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_cloud_md_get_vpcs.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_aws_cloud_md_get_vpcs.html keywords: aws, workflows, virtual,
#   • chunk_id  : ff5775bb-de95-4acc-a7a3-aed23555861b
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_cloud_md_get_vpcs.adoc'}
#     preview   : .Curl example [source,curl] curl --request GET \ --location "https://api.bluexp.netapp.com/occm/api/
#   • chunk_id  : a235fffa-5ad1-480e-b926-ed40675292b0
#     metadata  : {'source': '../bluexp-dataset/cm/wf_aws_cloud_md_get_vpcs.adoc'}
#     preview   : === Step 1. Select the region to use  Perform the workflow link:wf_aws_cloud_md_get_regions.html#get
# ----------------------------------------
# 📄 Source file: 71f89d4a-082e-4c9f-9f61-a66e2ea76f37
#   • chunk_id  : c5d0f963-cd05-4c19-a34b-b29646cd32fc
#     metadata  : {'source': '../bluexp-dataset/cm/wf_azure_cloud_md_get_regions.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_azure_cloud_md_get_regions.html keywords: cloud, volumes, onta
# ----------------------------------------
# 📄 Source file: 75e966a3-b003-4542-b95d-c226a97c597d
#   • chunk_id  : 1de6aeb7-c421-41ca-88ee-b0c6d243521a
#     metadata  : {'source': '../bluexp-dataset/cm/wf_onprem_ontap_delete_volume.adoc'}
#     preview   : --- sidebar: sidebar permalink: cm/wf_onprem_ontap_delete_volume.html keywords: delete, volume, blue
# ----------------------------------------

# %%
G = nx.DiGraph()
repo_path = "../bluexp-dataset"

for dirpath, subdirs, files in os.walk(repo_path):
    dir_node = os.path.normpath(dirpath)
    G.add_node(dir_node, type="dir")
    for sd in subdirs:
        G.add_edge(dir_node,
                   os.path.normpath(os.path.join(dirpath, sd)),
                   type="contains")
    for f in files:
        file_node = os.path.normpath(os.path.join(dirpath, f))
        G.add_node(file_node, type="file")
        G.add_edge(dir_node, file_node, type="contains")

# %% [markdown]
# ### Hybrid Approach - Utilizing Generated Embeddings in Tandem with a Directed Graph

# %%
retriever = index.as_retriever(similarity_top_k=5)

def hybrid_search(query, top_k=5, α=0.5):
    vec_hits = retriever.retrieve(query)
    
    scored = []
    for hit in vec_hits:
        path      = hit.metadata["source"]
        vec_score = hit.score
        
        # boosting files in small folders to give them more weight
        parent     = os.path.dirname(path)
        sib_count  = len(list(G.successors(parent))) or 1
        graph_boost = 1.0 / sib_count
        
        # combine scores
        combined = α * vec_score + (1 - α) * graph_boost
        scored.append((combined, hit))
    
    return [h for _, h in sorted(scored, key=lambda x: -x[0])]

# Testing:
for r in hybrid_search("how do i setup auth for bluexp", top_k=10):
    print(r.metadata["source"], f"(score: {r.score:.3f})")
# Out:
# ../bluexp-dataset/platform/register_service.adoc (score: 0.569)
# ../bluexp-dataset/platform/get_nss_key.adoc (score: 0.528)
# ../bluexp-dataset/platform/use_rest_apis.adoc (score: 0.524)
# ../bluexp-dataset/cm/security.adoc (score: 0.535)
# ../bluexp-dataset/cm/wf_gcp_cloud_create_we_byol.adoc (score: 0.506)
