# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
from IPython.display import JSON
from IPython.display import display

import json

# %pip install unstructured-client
# %pip install unstructured
# %pip install python-pptx
# %pip install PyYAML

import os
import yaml
import subprocess
import sys
import yaml

from unstructured_client.models import shared
from unstructured_client.models.errors import SDKError


from unstructured.partition.text import partition_text
from pathlib import Path

# %pip install chromadb
import chromadb #in-memory vector database
# Out:
# Requirement already satisfied: unstructured-client in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (0.37.2)
# Requirement already satisfied: aiofiles>=24.1.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured-client) (24.1.0)
# Requirement already satisfied: cryptography>=3.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured-client) (45.0.4)
# Requirement already satisfied: httpx>=0.27.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured-client) (0.28.1)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured-client) (1.6.0)
# Requirement already satisfied: pydantic>=2.11.2 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured-client) (2.11.7)
# Requirement already satisfied: pypdf>=4.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured-client) (5.6.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured-client) (1.0.0)
# Requirement already satisfied: cffi>=1.14 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from cryptography>=3.1->unstructured-client) (1.17.1)
# Requirement already satisfied: pycparser in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from cffi>=1.14->cryptography>=3.1->unstructured-client) (2.22)
# Requirement already satisfied: anyio in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from httpx>=0.27.0->unstructured-client) (4.9.0)
# Requirement already satisfied: certifi in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from httpx>=0.27.0->unstructured-client) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from httpx>=0.27.0->unstructured-client) (1.0.9)
# Requirement already satisfied: idna in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from httpx>=0.27.0->unstructured-client) (3.10)
# Requirement already satisfied: h11>=0.16 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from pydantic>=2.11.2->unstructured-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from pydantic>=2.11.2->unstructured-client) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from pydantic>=2.11.2->unstructured-client) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from pydantic>=2.11.2->unstructured-client) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from requests-toolbelt>=1.0.0->unstructured-client) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from requests<3.0.0,>=2.0.1->requests-toolbelt>=1.0.0->unstructured-client) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from requests<3.0.0,>=2.0.1->requests-toolbelt>=1.0.0->unstructured-client) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from anyio->httpx>=0.27.0->unstructured-client) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: unstructured in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (0.17.2)
# Requirement already satisfied: chardet in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (5.4.0)
# Requirement already satisfied: nltk in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (4.13.4)
# Requirement already satisfied: emoji in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (2.14.1)
# Requirement already satisfied: dataclasses-json in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (2025.2.18)
# Requirement already satisfied: langdetect in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (2.3.1)
# Requirement already satisfied: rapidfuzz in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (3.13.0)
# Requirement already satisfied: backoff in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (4.14.0)
# Requirement already satisfied: unstructured-client in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (0.37.2)
# Requirement already satisfied: wrapt in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (1.17.2)
# Requirement already satisfied: tqdm in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (4.67.1)
# Requirement already satisfied: psutil in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (7.0.0)
# Requirement already satisfied: python-oxmsg in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: html5lib in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from beautifulsoup4->unstructured) (2.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from dataclasses-json->unstructured) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (25.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.1.0)
# Requirement already satisfied: six>=1.9 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from html5lib->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from nltk->unstructured) (8.2.1)
# Requirement already satisfied: joblib in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from nltk->unstructured) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from nltk->unstructured) (2024.11.6)
# Requirement already satisfied: olefile in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from requests->unstructured) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from requests->unstructured) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from requests->unstructured) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from requests->unstructured) (2025.6.15)
# Requirement already satisfied: aiofiles>=24.1.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured-client->unstructured) (24.1.0)
# Requirement already satisfied: cryptography>=3.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured-client->unstructured) (45.0.4)
# Requirement already satisfied: httpx>=0.27.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pydantic>=2.11.2 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured-client->unstructured) (2.11.7)
# Requirement already satisfied: pypdf>=4.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured-client->unstructured) (5.6.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.14 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: pycparser in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from cffi>=1.14->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Requirement already satisfied: anyio in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-pptx in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (1.0.2)
# Requirement already satisfied: Pillow>=3.3.2 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from python-pptx) (11.2.1)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from python-pptx) (3.2.5)
# Requirement already satisfied: lxml>=3.1.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from python-pptx) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from python-pptx) (4.14.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: PyYAML in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (6.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: chromadb in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (1.0.13)
# Requirement already satisfied: build>=1.0.3 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (2.11.7)
# Requirement already satisfied: pybase64>=1.4.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.3)
# Requirement already satisfied: numpy>=1.22.5 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (2.3.1)
# Requirement already satisfied: posthog>=2.4.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (4.14.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (0.21.2)
# Requirement already satisfied: pypika>=0.48.9 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (1.73.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from chromadb) (4.24.0)
# Requirement already satisfied: packaging>=19.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: anyio in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: certifi in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11>=0.16 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.25.1)
# Requirement already satisfied: six>=1.9.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.32.4)
# Requirement already satisfied: requests-oauthlib in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.55b1)
# Requirement already satisfied: backoff>=1.10.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb) (0.33.0)
# Requirement already satisfied: filelock in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.5.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.1.5)
# Requirement already satisfied: click>=8.0.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/dornlee/CodeBase/DATA992/V2/DATA992-Summer-2025-Team1/myenv/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Cell 2 Extract documentation texts
def extract_texts(repo_path, extensions=("adoc", "json", "yaml", "yml")):
    """
    Extract texts from files with specified extensions in the given repository path.
    """
    texts = []
    
    # Fix: Process all extensions, not just the first one
    for ext in extensions:
        file_paths = list(Path(repo_path).rglob(f"*.{ext}"))
        print(f"Found {len(file_paths)} .{ext} files")
        
        for path in file_paths:
            try:
                with open(path, 'r', encoding='utf-8', errors='ignore') as f:
                    content = f.read()
                    if content.strip():  # Only add non-empty files
                        texts.append((str(path), content, ext))
            except Exception as e:
                print(f"Error reading {path}: {e}")
                continue
    
    return texts

docs = extract_texts("../bluexp-dataset")
print(f"Extracted {len(docs)} files")

# Export extracted docs to a JSON file
try:
    with open('cell_2_extracted_docs.json', 'w', encoding='utf-8') as f:
        json.dump(docs, f, indent=2, ensure_ascii=False)
    print(f"✅ Extracted docs exported to 'extracted_docs.json'")
except Exception as e:
    print(f"❌ Error exporting extracted docs: {e}")

print("\nEach inner array contains three elements:\n"
    "1. The file path (e.g., '../bluexp-dataset/legal-notices.adoc').\n"
    "2. The content of the file (a long string).\n"
    "3. The file type (e.g., 'adoc').\n"
    "Thus, each JSON array contains 3 elements.")
# Out:
# Found 158 .adoc files
# Found 16 .json files
# Found 1 .yaml files
# Found 18 .yml files
# Extracted 193 files
# ✅ Extracted docs exported to 'extracted_docs.json'
#
# Each inner array contains three elements:
# 1. The file path (e.g., '../bluexp-dataset/legal-notices.adoc').
# 2. The content of the file (a long string).
# 3. The file type (e.g., 'adoc').
# Thus, each JSON array contains 3 elements.

# %% [markdown]
# ## Cleaning and Preparation

# %%
##Cell 3

import re
import unicodedata
from typing import List, Tuple

def clean_asciidoc_content(content: str) -> str:
    """
    Comprehensive cleaning function for AsciiDoc content
    """
    # Remove AsciiDoc metadata and frontmatter
    content = re.sub(r'^---[\s\S]*?---\n?', '', content, flags=re.MULTILINE)
    
    # Remove AsciiDoc directives and attributes
    content = re.sub(r'^\s*:[^:\n]+:.*$', '', content, flags=re.MULTILINE)  # :attribute: value
    content = re.sub(r'^\s*\[.*?\]\s*$', '', content, flags=re.MULTILINE)    # [attribute]
    
    # Remove AsciiDoc include directives
    content = re.sub(r'include::[^\[\]]*\[.*?\]', '', content)
    
    # Remove AsciiDoc cross-references and anchors
    content = re.sub(r'<<[^>]*>>', '', content)
    content = re.sub(r'\[\[.*?\]\]', '', content)
    content = re.sub(r'anchor:[^\[\]]*\[.*?\]', '', content)
    
    # Remove AsciiDoc links but keep the text
    content = re.sub(r'https?://[^\s\[\]]+\[([^\]]*)\]', r'\1', content)  # link[text] -> text
    content = re.sub(r'link:[^\[\]]+\[([^\]]*)\]', r'\1', content)         # link:url[text] -> text
    
    # Remove or replace AsciiDoc formatting
    content = re.sub(r'\*\*([^*]+)\*\*', r'\1', content)  # **bold** -> text
    content = re.sub(r'\*([^*]+)\*', r'\1', content)      # *emphasis* -> text
    content = re.sub(r'`([^`]+)`', r'\1', content)        # `code` -> code
    content = re.sub(r'_([^_]+)_', r'\1', content)        # _italic_ -> text
    
    # Remove AsciiDoc headers but keep the text
    content = re.sub(r'^=+\s*(.+)$', r'\1', content, flags=re.MULTILINE)
    
    # Remove AsciiDoc comments
    content = re.sub(r'^//.*$', '', content, flags=re.MULTILINE)
    content = re.sub(r'////[\s\S]*?////', '', content, flags=re.MULTILINE)
    
    # Remove AsciiDoc tables and lists formatting
    content = re.sub(r'^\|.*$', '', content, flags=re.MULTILINE)  # Table rows
    content = re.sub(r'^\s*\*+\s+', '', content, flags=re.MULTILINE)  # Bullet lists
    content = re.sub(r'^\s*\.+\s+', '', content, flags=re.MULTILINE)  # Numbered lists
    
    # Remove AsciiDoc blocks
    content = re.sub(r'^-{4,}$.*?^-{4,}$', '', content, flags=re.MULTILINE | re.DOTALL)
    content = re.sub(r'^={4,}$.*?^={4,}$', '', content, flags=re.MULTILINE | re.DOTALL)
    content = re.sub(r'^\+{4,}$.*?^\+{4,}$', '', content, flags=re.MULTILINE | re.DOTALL)
    
    return content

def clean_general_text(text: str) -> str:
    """
    General text cleaning for any content type
    """
    # Normalize unicode characters
    text = unicodedata.normalize('NFKD', text)
    
    # Remove or replace special characters
    text = re.sub(r'[^\w\s\.\,\!\?\-\(\)\:\;]', ' ', text)
    
    # Clean up whitespace
    text = re.sub(r'\s+', ' ', text)  # Multiple spaces to single space
    text = re.sub(r'\n+', ' ', text)  # Multiple newlines to space
    text = re.sub(r'\t+', ' ', text)  # Tabs to space
    
    # Remove excessive punctuation
    text = re.sub(r'[\.]{3,}', '...', text)  # Multiple dots to ellipsis
    text = re.sub(r'[!]{2,}', '!', text)     # Multiple exclamations
    text = re.sub(r'[\?]{2,}', '?', text)    # Multiple questions
    
    # Remove standalone punctuation and short meaningless sequences
    text = re.sub(r'\b[^\w\s]{1,3}\b', ' ', text)
    
    # Clean up sentence structure
    text = re.sub(r'\s+([\.!?])', r'\1', text)  # Remove space before punctuation
    text = re.sub(r'([\.!?])\s*([a-z])', r'\1 \2', text)  # Ensure space after sentence end

    return text.strip()

cleaned_training_docs = []


for file_path, content, file_type in docs:
    print(f"Processing: {file_path}")
    
    # Step 1: Clean AsciiDoc-specific content if applicable
    if file_type == 'adoc':
        cleaned_content = clean_asciidoc_content(content)
    else:
        cleaned_content = content
    
    # Step 2: General text cleaning
    cleaned_content = clean_general_text(cleaned_content)

    # Append the cleaned content and file type to the training_texts list
    cleaned_training_docs.append((file_path, cleaned_content, file_type))

# Export cleaned training texts to a JSON file
output_file = 'cell_3_cleaned_training_docs.json'
try:
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(cleaned_training_docs, f, indent=2, ensure_ascii=False)
    print(f"✅ Cleaned training texts exported to '{output_file}'")
except Exception as e:
    print(f"❌ Error exporting cleaned training texts: {e}")
# Out:
# Processing: ../bluexp-dataset/legal-notices.adoc
# Processing: ../bluexp-dataset/platform/aa_concepts.adoc
# Processing: ../bluexp-dataset/platform/create_user_token.adoc
# Processing: ../bluexp-dataset/platform/http_details.adoc
# Processing: ../bluexp-dataset/platform/get_identifiers.adoc
# Processing: ../bluexp-dataset/platform/workflows_tasks.adoc
# Processing: ../bluexp-dataset/platform/user_access_tokens.adoc
# Processing: ../bluexp-dataset/platform/concepts.adoc
# Processing: ../bluexp-dataset/platform/overview.adoc
# Processing: ../bluexp-dataset/platform/register_service.adoc
# Processing: ../bluexp-dataset/platform/api_explorer.adoc
# Processing: ../bluexp-dataset/platform/get_nss_key.adoc
# Processing: ../bluexp-dataset/platform/create_service_token.adoc
# Processing: ../bluexp-dataset/platform/additional_considerations.adoc
# Processing: ../bluexp-dataset/platform/use_rest_apis.adoc
# Processing: ../bluexp-dataset/platform/connectors_clients.adoc
# Processing: ../bluexp-dataset/platform/grant_types.adoc
# Processing: ../bluexp-dataset/support/additional_resources.adoc
# Processing: ../bluexp-dataset/automate/blogs.adoc
# Processing: ../bluexp-dataset/automate/overview.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_ontap_create_cifs.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_ontap_create_vol_nfs.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_cloud_md_create_account.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_ontap_get_volumes.adoc
# Processing: ../bluexp-dataset/cm/wf_common_identity_get_accounts.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_ontap_add_disks_aggr.adoc
# Processing: ../bluexp-dataset/cm/wf_onprem_ontap_create_vol_cifs.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_zones.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_cloud_create_we_paygo.adoc
# Processing: ../bluexp-dataset/cm/wf_onprem_ontap_get_aggrs.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_ontap_delete_cifs.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_ontap_create_quote.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_snapshot_policies.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_cloud_md_get_vnets.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_ontap_create_vol_nfs.adoc
# Processing: ../bluexp-dataset/cm/api_ref_resources.adoc
# Processing: ../bluexp-dataset/cm/wf_onprem_ontap_modify_volume.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_service_accounts.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_ontap_delete_aggr.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_ontap_get_cifs.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_ontap_add_disks_aggr.adoc
# Processing: ../bluexp-dataset/cm/cvo_deployment.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_cloud_md_get_regions.adoc
# Processing: ../bluexp-dataset/cm/wf_onprem_ontap_create_vol_iscsi.adoc
# Processing: ../bluexp-dataset/cm/wf_common_identity_create_nss_key.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_cloud_md_get_permutations.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_cloud_md_get_route_tables.adoc
# Processing: ../bluexp-dataset/cm/wf_common_ontap_repl_create_repl.adoc
# Processing: ../bluexp-dataset/cm/wf_common_identity_get_supported_srv.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_ontap_get_aggrs.adoc
# Processing: ../bluexp-dataset/cm/wf_common_occm_attach_subscription.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_ontap_get_igroups.adoc
# Processing: ../bluexp-dataset/cm/wf_onprem_flexgroup_ontap_create_vol.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_ontap_create_aggr.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_ontap_modify_volume.adoc
# Processing: ../bluexp-dataset/cm/wf_common_ontap_repl_get_ic_lifs.adoc
# Processing: ../bluexp-dataset/cm/wf_onprem_get_wes.adoc
# Processing: ../bluexp-dataset/cm/wf_common_ontap_repl_update_repl.adoc
# Processing: ../bluexp-dataset/cm/wf_common_identity_get_tenants.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_ontap_modify_volume.adoc
# Processing: ../bluexp-dataset/cm/wf_common_ontap_repl_get_rel_we_status.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_cloud_get_wes.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_ontap_get_aggrs.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_cloud_create_we_paygo.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_ontap_delete_volume.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_ontap_get_cifs.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_ontap_create_aggr.adoc
# Processing: ../bluexp-dataset/cm/wf_onprem_ontap_get_volumes.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_create_we_byol.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_ontap_get_igroups.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_ontap_create_vol_iscsi.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_ontap_create_vol_iscsi.adoc
# Processing: ../bluexp-dataset/cm/wf_common_identity_get_provider_accounts.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_ontap_create_cifs.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_supported_features.adoc
# Processing: ../bluexp-dataset/cm/wf_common_ontap_repl_get_rel_status.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_ontap_get_volumes.adoc
# Processing: ../bluexp-dataset/cm/security.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_ontap_get_cifs.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_cloud_md_get_availability_zones.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_ontap_get_aggrs.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_instance_type_nosupport.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_create_buckets.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_cloud_md_get_ebs_vol_types.adoc
# Processing: ../bluexp-dataset/cm/wf_common_identity_get_nss_key.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_ontap_create_quote.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_supported_tiers.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_create_we_paygo.adoc
# Processing: ../bluexp-dataset/cm/wf_onprem_discover_wes.adoc
# Processing: ../bluexp-dataset/cm/wf_common_ontap_repl_get_we_schedules.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_cloud_create_we_capacity.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_cloud_create_we_byol.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_buckets.adoc
# Processing: ../bluexp-dataset/cm/your_api_call.adoc
# Processing: ../bluexp-dataset/cm/wf_common_ontap_md_get_snapmirror_policies.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_cloud_get_wes.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_ontap_create_quote.adoc
# Processing: ../bluexp-dataset/cm/overview.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_ontap_modify_volume.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_ontap_delete_cifs.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_ontap_create_vol_cifs.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_cloud_add_capacity.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_delete_we.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_cloud_md_get_key_pairs.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_vpcs.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_cloud_md_get_permutations.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_disk_types.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_ontap_delete_volume.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_ontap_get_volumes.adoc
# Processing: ../bluexp-dataset/cm/wf_onprem_ontap_create_vol_nfs.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_ontap_delete_volume.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_cloud_md_get_packages.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_permutations.adoc
# Processing: ../bluexp-dataset/cm/wf_common_identity_get_saas_mp.adoc
# Processing: ../bluexp-dataset/cm/wf_common_identity_delete_nss_key.adoc
# Processing: ../bluexp-dataset/cm/wf_common_ontap_repl_get_sm_rels.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_ontap_get_igroups.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_get_wes.adoc
# Processing: ../bluexp-dataset/cm/api_ref_definitions.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_cloud_create_we_byol.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_cloud_md_get_storage_account_types.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_cloud_delete_we.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_ontap_delete_aggr.adoc
# Processing: ../bluexp-dataset/cm/prepare.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_ontap_create_vol_iscsi.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_network_requirements.adoc
# Processing: ../bluexp-dataset/cm/wf_onprem_ontap_get_cifs.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_tag_keys.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_projects.adoc
# Processing: ../bluexp-dataset/cm/wf_common_occm_get_task.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_ontap_add_disks_aggr.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_ontap_create_aggr.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_ontap_create_vol_cifs.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_ontap_create_vol_nfs.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_cloud_create_we_capacity.adoc
# Processing: ../bluexp-dataset/cm/api_reference.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_ontap_delete_aggr.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_create_we_capacity.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_cloud_delete_we.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_cloud_md_get_packages.adoc
# Processing: ../bluexp-dataset/cm/wf_common_ontap_repl_delete_repl.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_encryption_keys.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_regions.adoc
# Processing: ../bluexp-dataset/cm/wf_onprem_before.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_ontap_create_vol_cifs.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_cloud_md_create_account.adoc
# Processing: ../bluexp-dataset/cm/workflow_processes.adoc
# Processing: ../bluexp-dataset/cm/wf_common_before.adoc
# Processing: ../bluexp-dataset/cm/wf_common_identity_get_nss_keys.adoc
# Processing: ../bluexp-dataset/cm/wf_cvo_before.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_ontap_delete_cifs.adoc
# Processing: ../bluexp-dataset/cm/wf_azuregcp_ontap_create_aggr.adoc
# Processing: ../bluexp-dataset/cm/wf_common_ontap_md_get_snapmirror_svm_policies.adoc
# Processing: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_packages.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_ontap_create_cifs.adoc
# Processing: ../bluexp-dataset/cm/wf_aws_cloud_md_get_vpcs.adoc
# Processing: ../bluexp-dataset/cm/wf_azure_cloud_md_get_regions.adoc
# Processing: ../bluexp-dataset/cm/wf_onprem_ontap_delete_volume.adoc
# Processing: ../bluexp-dataset/credential/credential.json
# Processing: ../bluexp-dataset/credential/credential-x-doc.json
# Processing: ../bluexp-dataset/cbs/cbs-x-doc.json
# Processing: ../bluexp-dataset/cbs/cbs.json
# Processing: ../bluexp-dataset/ipa/ipa-x-doc.json
# Processing: ../bluexp-dataset/ipa/ipa.json
# Processing: ../bluexp-dataset/tenancy/tenancy-x-doc.json
# Processing: ../bluexp-dataset/tenancy/tenancy.json
# Processing: ../bluexp-dataset/copysync/copysync-x-doc.json
# Processing: ../bluexp-dataset/copysync/copysync.json
# Processing: ../bluexp-dataset/fsx/fsx.json
# Processing: ../bluexp-dataset/fsx/fsx-x-doc.json
# Processing: ../bluexp-dataset/audit/audit.json
# Processing: ../bluexp-dataset/audit/audit-x-doc.json
# Processing: ../bluexp-dataset/dw/dw.json
# Processing: ../bluexp-dataset/dw/dw-x-doc.json
# Processing: ../bluexp-dataset/tenancyv4/tenancyv4.yaml
# Processing: ../bluexp-dataset/_index.yml
# Processing: ../bluexp-dataset/project.yml
# Processing: ../bluexp-dataset/api-cm/sidebar.yml
# Processing: ../bluexp-dataset/credential/sidebar.yml
# Processing: ../bluexp-dataset/cbs/sidebar.yml
# Processing: ../bluexp-dataset/ipa/sidebar.yml
# Processing: ../bluexp-dataset/tenancy/sidebar.yml
# Processing: ../bluexp-dataset/platform/sidebar.yml
# Processing: ../bluexp-dataset/workflows/sidebar.yml
# Processing: ../bluexp-dataset/copysync/sidebar.yml
# Processing: ../bluexp-dataset/fsx/sidebar.yml
# Processing: ../bluexp-dataset/audit/sidebar.yml
# Processing: ../bluexp-dataset/support/sidebar.yml
# Processing: ../bluexp-dataset/automate/sidebar.yml
# Processing: ../bluexp-dataset/tenancyv4/sidebar.yml
# Processing: ../bluexp-dataset/tenancyv4/tenancyv4-x-doc.yml
# Processing: ../bluexp-dataset/dw/sidebar.yml
# Processing: ../bluexp-dataset/cm/sidebar.yml
# ✅ Cleaned training texts exported to 'cell_3_cleaned_training_docs.json'

# %% [markdown]
# ## Process cleaned docs with unstructured library

# %%
##Cell 4
import json

def process_partition_text(docs):
    all_elements = []

    for i, doc in enumerate(docs):
        file_path = doc[0]
        print(f"Processing file: {file_path}")
        try:
            # Use partition_text for direct content processing
            elements = partition_text(filename=file_path)
            element_dict = [el.to_dict() for el in elements]
            all_elements.extend(element_dict)

            print(f"Extracted {len(element_dict)} elements from {doc[0]}")
        except ValueError as e:
            print(f"Error processing {doc[0]}: {e}")
        except Exception as e:
            print(f"Unexpected error: {e}")

    return all_elements

doc_element_results = process_partition_text(cleaned_training_docs)
# Out:
# Processing file: ../bluexp-dataset/legal-notices.adoc
# Extracted 9 elements from ../bluexp-dataset/legal-notices.adoc
# Processing file: ../bluexp-dataset/platform/aa_concepts.adoc
# Extracted 21 elements from ../bluexp-dataset/platform/aa_concepts.adoc
# Processing file: ../bluexp-dataset/platform/create_user_token.adoc
# Extracted 124 elements from ../bluexp-dataset/platform/create_user_token.adoc
# Processing file: ../bluexp-dataset/platform/http_details.adoc
# Extracted 24 elements from ../bluexp-dataset/platform/http_details.adoc
# Processing file: ../bluexp-dataset/platform/get_identifiers.adoc
# Extracted 47 elements from ../bluexp-dataset/platform/get_identifiers.adoc
# Processing file: ../bluexp-dataset/platform/workflows_tasks.adoc
# Extracted 42 elements from ../bluexp-dataset/platform/workflows_tasks.adoc
# Processing file: ../bluexp-dataset/platform/user_access_tokens.adoc
# Extracted 63 elements from ../bluexp-dataset/platform/user_access_tokens.adoc
# Processing file: ../bluexp-dataset/platform/concepts.adoc
# Extracted 23 elements from ../bluexp-dataset/platform/concepts.adoc
# Processing file: ../bluexp-dataset/platform/overview.adoc
# Extracted 7 elements from ../bluexp-dataset/platform/overview.adoc
# Processing file: ../bluexp-dataset/platform/register_service.adoc
# Extracted 25 elements from ../bluexp-dataset/platform/register_service.adoc
# Processing file: ../bluexp-dataset/platform/api_explorer.adoc
# Extracted 24 elements from ../bluexp-dataset/platform/api_explorer.adoc
# Processing file: ../bluexp-dataset/platform/get_nss_key.adoc
# Extracted 20 elements from ../bluexp-dataset/platform/get_nss_key.adoc
# Processing file: ../bluexp-dataset/platform/create_service_token.adoc
# Extracted 54 elements from ../bluexp-dataset/platform/create_service_token.adoc
# Processing file: ../bluexp-dataset/platform/additional_considerations.adoc
# Extracted 14 elements from ../bluexp-dataset/platform/additional_considerations.adoc
# Processing file: ../bluexp-dataset/platform/use_rest_apis.adoc
# Extracted 43 elements from ../bluexp-dataset/platform/use_rest_apis.adoc
# Processing file: ../bluexp-dataset/platform/connectors_clients.adoc
# Extracted 13 elements from ../bluexp-dataset/platform/connectors_clients.adoc
# Processing file: ../bluexp-dataset/platform/grant_types.adoc
# Extracted 43 elements from ../bluexp-dataset/platform/grant_types.adoc
# Processing file: ../bluexp-dataset/support/additional_resources.adoc
# Extracted 23 elements from ../bluexp-dataset/support/additional_resources.adoc
# Processing file: ../bluexp-dataset/automate/blogs.adoc
# Extracted 66 elements from ../bluexp-dataset/automate/blogs.adoc
# Processing file: ../bluexp-dataset/automate/overview.adoc
# Extracted 16 elements from ../bluexp-dataset/automate/overview.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_ontap_create_cifs.adoc
# Extracted 138 elements from ../bluexp-dataset/cm/wf_gcp_ontap_create_cifs.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_ontap_create_vol_nfs.adoc
# Extracted 134 elements from ../bluexp-dataset/cm/wf_azure_ontap_create_vol_nfs.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_cloud_md_create_account.adoc
# Extracted 47 elements from ../bluexp-dataset/cm/wf_azure_cloud_md_create_account.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_ontap_get_volumes.adoc
# Extracted 264 elements from ../bluexp-dataset/cm/wf_aws_ontap_get_volumes.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_identity_get_accounts.adoc
# Extracted 66 elements from ../bluexp-dataset/cm/wf_common_identity_get_accounts.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_ontap_add_disks_aggr.adoc
# Extracted 66 elements from ../bluexp-dataset/cm/wf_azure_ontap_add_disks_aggr.adoc
# Processing file: ../bluexp-dataset/cm/wf_onprem_ontap_create_vol_cifs.adoc
# Extracted 62 elements from ../bluexp-dataset/cm/wf_onprem_ontap_create_vol_cifs.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_zones.adoc
# Extracted 80 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_get_zones.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_cloud_create_we_paygo.adoc
# Extracted 317 elements from ../bluexp-dataset/cm/wf_azure_cloud_create_we_paygo.adoc
# Processing file: ../bluexp-dataset/cm/wf_onprem_ontap_get_aggrs.adoc
# Extracted 85 elements from ../bluexp-dataset/cm/wf_onprem_ontap_get_aggrs.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_ontap_delete_cifs.adoc
# Extracted 70 elements from ../bluexp-dataset/cm/wf_azure_ontap_delete_cifs.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_ontap_create_quote.adoc
# Extracted 107 elements from ../bluexp-dataset/cm/wf_gcp_ontap_create_quote.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_snapshot_policies.adoc
# Extracted 49 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_snapshot_policies.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_cloud_md_get_vnets.adoc
# Extracted 256 elements from ../bluexp-dataset/cm/wf_azure_cloud_md_get_vnets.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_ontap_create_vol_nfs.adoc
# Extracted 158 elements from ../bluexp-dataset/cm/wf_gcp_ontap_create_vol_nfs.adoc
# Processing file: ../bluexp-dataset/cm/api_ref_resources.adoc
# Extracted 9047 elements from ../bluexp-dataset/cm/api_ref_resources.adoc
# Processing file: ../bluexp-dataset/cm/wf_onprem_ontap_modify_volume.adoc
# Extracted 43 elements from ../bluexp-dataset/cm/wf_onprem_ontap_modify_volume.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_service_accounts.adoc
# Extracted 69 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_get_service_accounts.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_ontap_delete_aggr.adoc
# Extracted 110 elements from ../bluexp-dataset/cm/wf_azure_ontap_delete_aggr.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_ontap_get_cifs.adoc
# Extracted 102 elements from ../bluexp-dataset/cm/wf_aws_ontap_get_cifs.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_ontap_add_disks_aggr.adoc
# Extracted 60 elements from ../bluexp-dataset/cm/wf_gcp_ontap_add_disks_aggr.adoc
# Processing file: ../bluexp-dataset/cm/cvo_deployment.adoc
# Extracted 4 elements from ../bluexp-dataset/cm/cvo_deployment.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_cloud_md_get_regions.adoc
# Extracted 122 elements from ../bluexp-dataset/cm/wf_aws_cloud_md_get_regions.adoc
# Processing file: ../bluexp-dataset/cm/wf_onprem_ontap_create_vol_iscsi.adoc
# Extracted 125 elements from ../bluexp-dataset/cm/wf_onprem_ontap_create_vol_iscsi.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_identity_create_nss_key.adoc
# Extracted 50 elements from ../bluexp-dataset/cm/wf_common_identity_create_nss_key.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_cloud_md_get_permutations.adoc
# Extracted 46 elements from ../bluexp-dataset/cm/wf_aws_cloud_md_get_permutations.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_cloud_md_get_route_tables.adoc
# Extracted 123 elements from ../bluexp-dataset/cm/wf_aws_cloud_md_get_route_tables.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_ontap_repl_create_repl.adoc
# Extracted 65 elements from ../bluexp-dataset/cm/wf_common_ontap_repl_create_repl.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_identity_get_supported_srv.adoc
# Extracted 163 elements from ../bluexp-dataset/cm/wf_common_identity_get_supported_srv.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_ontap_get_aggrs.adoc
# Extracted 599 elements from ../bluexp-dataset/cm/wf_aws_ontap_get_aggrs.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_occm_attach_subscription.adoc
# Extracted 42 elements from ../bluexp-dataset/cm/wf_common_occm_attach_subscription.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_ontap_get_igroups.adoc
# Extracted 103 elements from ../bluexp-dataset/cm/wf_aws_ontap_get_igroups.adoc
# Processing file: ../bluexp-dataset/cm/wf_onprem_flexgroup_ontap_create_vol.adoc
# Extracted 92 elements from ../bluexp-dataset/cm/wf_onprem_flexgroup_ontap_create_vol.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_ontap_create_aggr.adoc
# Extracted 77 elements from ../bluexp-dataset/cm/wf_gcp_ontap_create_aggr.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_ontap_modify_volume.adoc
# Extracted 110 elements from ../bluexp-dataset/cm/wf_gcp_ontap_modify_volume.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_ontap_repl_get_ic_lifs.adoc
# Extracted 67 elements from ../bluexp-dataset/cm/wf_common_ontap_repl_get_ic_lifs.adoc
# Processing file: ../bluexp-dataset/cm/wf_onprem_get_wes.adoc
# Extracted 62 elements from ../bluexp-dataset/cm/wf_onprem_get_wes.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_ontap_repl_update_repl.adoc
# Extracted 30 elements from ../bluexp-dataset/cm/wf_common_ontap_repl_update_repl.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_identity_get_tenants.adoc
# Extracted 47 elements from ../bluexp-dataset/cm/wf_common_identity_get_tenants.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_ontap_modify_volume.adoc
# Extracted 128 elements from ../bluexp-dataset/cm/wf_azure_ontap_modify_volume.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_ontap_repl_get_rel_we_status.adoc
# Extracted 130 elements from ../bluexp-dataset/cm/wf_common_ontap_repl_get_rel_we_status.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_cloud_get_wes.adoc
# Extracted 213 elements from ../bluexp-dataset/cm/wf_aws_cloud_get_wes.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_ontap_get_aggrs.adoc
# Extracted 387 elements from ../bluexp-dataset/cm/wf_azure_ontap_get_aggrs.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_cloud_create_we_paygo.adoc
# Extracted 236 elements from ../bluexp-dataset/cm/wf_aws_cloud_create_we_paygo.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_ontap_delete_volume.adoc
# Extracted 77 elements from ../bluexp-dataset/cm/wf_aws_ontap_delete_volume.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_ontap_get_cifs.adoc
# Extracted 95 elements from ../bluexp-dataset/cm/wf_azure_ontap_get_cifs.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_ontap_create_aggr.adoc
# Extracted 114 elements from ../bluexp-dataset/cm/wf_aws_ontap_create_aggr.adoc
# Processing file: ../bluexp-dataset/cm/wf_onprem_ontap_get_volumes.adoc
# Extracted 147 elements from ../bluexp-dataset/cm/wf_onprem_ontap_get_volumes.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_create_we_byol.adoc
# Extracted 239 elements from ../bluexp-dataset/cm/wf_gcp_cloud_create_we_byol.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_ontap_get_igroups.adoc
# Extracted 95 elements from ../bluexp-dataset/cm/wf_gcp_ontap_get_igroups.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_ontap_create_vol_iscsi.adoc
# Extracted 272 elements from ../bluexp-dataset/cm/wf_gcp_ontap_create_vol_iscsi.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_ontap_create_vol_iscsi.adoc
# Extracted 276 elements from ../bluexp-dataset/cm/wf_azure_ontap_create_vol_iscsi.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_identity_get_provider_accounts.adoc
# Extracted 56 elements from ../bluexp-dataset/cm/wf_common_identity_get_provider_accounts.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_ontap_create_cifs.adoc
# Extracted 150 elements from ../bluexp-dataset/cm/wf_aws_ontap_create_cifs.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_supported_features.adoc
# Extracted 77 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_get_supported_features.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_ontap_repl_get_rel_status.adoc
# Extracted 131 elements from ../bluexp-dataset/cm/wf_common_ontap_repl_get_rel_status.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_ontap_get_volumes.adoc
# Extracted 253 elements from ../bluexp-dataset/cm/wf_gcp_ontap_get_volumes.adoc
# Processing file: ../bluexp-dataset/cm/security.adoc
# Extracted 15 elements from ../bluexp-dataset/cm/security.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_ontap_get_cifs.adoc
# Extracted 94 elements from ../bluexp-dataset/cm/wf_gcp_ontap_get_cifs.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_cloud_md_get_availability_zones.adoc
# Extracted 34 elements from ../bluexp-dataset/cm/wf_azure_cloud_md_get_availability_zones.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_ontap_get_aggrs.adoc
# Extracted 292 elements from ../bluexp-dataset/cm/wf_gcp_ontap_get_aggrs.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_instance_type_nosupport.adoc
# Extracted 94 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_get_instance_type_nosupport.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_create_buckets.adoc
# Extracted 63 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_create_buckets.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_cloud_md_get_ebs_vol_types.adoc
# Extracted 215 elements from ../bluexp-dataset/cm/wf_aws_cloud_md_get_ebs_vol_types.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_identity_get_nss_key.adoc
# Extracted 50 elements from ../bluexp-dataset/cm/wf_common_identity_get_nss_key.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_ontap_create_quote.adoc
# Extracted 123 elements from ../bluexp-dataset/cm/wf_azure_ontap_create_quote.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_supported_tiers.adoc
# Extracted 60 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_get_supported_tiers.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_create_we_paygo.adoc
# Extracted 273 elements from ../bluexp-dataset/cm/wf_gcp_cloud_create_we_paygo.adoc
# Processing file: ../bluexp-dataset/cm/wf_onprem_discover_wes.adoc
# Extracted 74 elements from ../bluexp-dataset/cm/wf_onprem_discover_wes.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_ontap_repl_get_we_schedules.adoc
# Extracted 80 elements from ../bluexp-dataset/cm/wf_common_ontap_repl_get_we_schedules.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_cloud_create_we_capacity.adoc
# Extracted 338 elements from ../bluexp-dataset/cm/wf_azure_cloud_create_we_capacity.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_cloud_create_we_byol.adoc
# Extracted 290 elements from ../bluexp-dataset/cm/wf_azure_cloud_create_we_byol.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_buckets.adoc
# Extracted 81 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_get_buckets.adoc
# Processing file: ../bluexp-dataset/cm/your_api_call.adoc
# Extracted 46 elements from ../bluexp-dataset/cm/your_api_call.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_ontap_md_get_snapmirror_policies.adoc
# Extracted 22 elements from ../bluexp-dataset/cm/wf_common_ontap_md_get_snapmirror_policies.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_cloud_get_wes.adoc
# Extracted 1026 elements from ../bluexp-dataset/cm/wf_azure_cloud_get_wes.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_ontap_create_quote.adoc
# Extracted 116 elements from ../bluexp-dataset/cm/wf_aws_ontap_create_quote.adoc
# Processing file: ../bluexp-dataset/cm/overview.adoc
# Extracted 30 elements from ../bluexp-dataset/cm/overview.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_ontap_modify_volume.adoc
# Extracted 114 elements from ../bluexp-dataset/cm/wf_aws_ontap_modify_volume.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_ontap_delete_cifs.adoc
# Extracted 90 elements from ../bluexp-dataset/cm/wf_aws_ontap_delete_cifs.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_ontap_create_vol_cifs.adoc
# Extracted 168 elements from ../bluexp-dataset/cm/wf_azure_ontap_create_vol_cifs.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_cloud_add_capacity.adoc
# Extracted 69 elements from ../bluexp-dataset/cm/wf_aws_cloud_add_capacity.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_delete_we.adoc
# Extracted 70 elements from ../bluexp-dataset/cm/wf_gcp_cloud_delete_we.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_cloud_md_get_key_pairs.adoc
# Extracted 74 elements from ../bluexp-dataset/cm/wf_aws_cloud_md_get_key_pairs.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_vpcs.adoc
# Extracted 92 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_get_vpcs.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_cloud_md_get_permutations.adoc
# Extracted 65 elements from ../bluexp-dataset/cm/wf_azure_cloud_md_get_permutations.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_disk_types.adoc
# Extracted 156 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_get_disk_types.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_ontap_delete_volume.adoc
# Extracted 76 elements from ../bluexp-dataset/cm/wf_azure_ontap_delete_volume.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_ontap_get_volumes.adoc
# Extracted 312 elements from ../bluexp-dataset/cm/wf_azure_ontap_get_volumes.adoc
# Processing file: ../bluexp-dataset/cm/wf_onprem_ontap_create_vol_nfs.adoc
# Extracted 68 elements from ../bluexp-dataset/cm/wf_onprem_ontap_create_vol_nfs.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_ontap_delete_volume.adoc
# Extracted 75 elements from ../bluexp-dataset/cm/wf_gcp_ontap_delete_volume.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_cloud_md_get_packages.adoc
# Extracted 46 elements from ../bluexp-dataset/cm/wf_azure_cloud_md_get_packages.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_permutations.adoc
# Extracted 48 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_get_permutations.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_identity_get_saas_mp.adoc
# Extracted 85 elements from ../bluexp-dataset/cm/wf_common_identity_get_saas_mp.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_identity_delete_nss_key.adoc
# Extracted 37 elements from ../bluexp-dataset/cm/wf_common_identity_delete_nss_key.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_ontap_repl_get_sm_rels.adoc
# Extracted 47 elements from ../bluexp-dataset/cm/wf_common_ontap_repl_get_sm_rels.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_ontap_get_igroups.adoc
# Extracted 95 elements from ../bluexp-dataset/cm/wf_azure_ontap_get_igroups.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_get_wes.adoc
# Extracted 228 elements from ../bluexp-dataset/cm/wf_gcp_cloud_get_wes.adoc
# Processing file: ../bluexp-dataset/cm/api_ref_definitions.adoc
# Extracted 4616 elements from ../bluexp-dataset/cm/api_ref_definitions.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_cloud_create_we_byol.adoc
# Extracted 205 elements from ../bluexp-dataset/cm/wf_aws_cloud_create_we_byol.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_cloud_md_get_storage_account_types.adoc
# Extracted 460 elements from ../bluexp-dataset/cm/wf_azure_cloud_md_get_storage_account_types.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_cloud_delete_we.adoc
# Extracted 76 elements from ../bluexp-dataset/cm/wf_azure_cloud_delete_we.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_ontap_delete_aggr.adoc
# Extracted 76 elements from ../bluexp-dataset/cm/wf_aws_ontap_delete_aggr.adoc
# Processing file: ../bluexp-dataset/cm/prepare.adoc
# Extracted 11 elements from ../bluexp-dataset/cm/prepare.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_ontap_create_vol_iscsi.adoc
# Extracted 278 elements from ../bluexp-dataset/cm/wf_aws_ontap_create_vol_iscsi.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_network_requirements.adoc
# Extracted 77 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_get_network_requirements.adoc
# Processing file: ../bluexp-dataset/cm/wf_onprem_ontap_get_cifs.adoc
# Extracted 49 elements from ../bluexp-dataset/cm/wf_onprem_ontap_get_cifs.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_tag_keys.adoc
# Extracted 203 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_get_tag_keys.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_projects.adoc
# Extracted 179 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_get_projects.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_occm_get_task.adoc
# Extracted 39 elements from ../bluexp-dataset/cm/wf_common_occm_get_task.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_ontap_add_disks_aggr.adoc
# Extracted 63 elements from ../bluexp-dataset/cm/wf_aws_ontap_add_disks_aggr.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_ontap_create_aggr.adoc
# Extracted 92 elements from ../bluexp-dataset/cm/wf_azure_ontap_create_aggr.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_ontap_create_vol_cifs.adoc
# Extracted 169 elements from ../bluexp-dataset/cm/wf_aws_ontap_create_vol_cifs.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_ontap_create_vol_nfs.adoc
# Extracted 167 elements from ../bluexp-dataset/cm/wf_aws_ontap_create_vol_nfs.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_cloud_create_we_capacity.adoc
# Extracted 417 elements from ../bluexp-dataset/cm/wf_aws_cloud_create_we_capacity.adoc
# Processing file: ../bluexp-dataset/cm/api_reference.adoc
# Extracted 8 elements from ../bluexp-dataset/cm/api_reference.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_ontap_delete_aggr.adoc
# Extracted 73 elements from ../bluexp-dataset/cm/wf_gcp_ontap_delete_aggr.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_create_we_capacity.adoc
# Extracted 290 elements from ../bluexp-dataset/cm/wf_gcp_cloud_create_we_capacity.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_cloud_delete_we.adoc
# Extracted 50 elements from ../bluexp-dataset/cm/wf_aws_cloud_delete_we.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_cloud_md_get_packages.adoc
# Extracted 41 elements from ../bluexp-dataset/cm/wf_aws_cloud_md_get_packages.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_ontap_repl_delete_repl.adoc
# Extracted 36 elements from ../bluexp-dataset/cm/wf_common_ontap_repl_delete_repl.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_encryption_keys.adoc
# Extracted 108 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_get_encryption_keys.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_regions.adoc
# Extracted 258 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_get_regions.adoc
# Processing file: ../bluexp-dataset/cm/wf_onprem_before.adoc
# Extracted 17 elements from ../bluexp-dataset/cm/wf_onprem_before.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_ontap_create_vol_cifs.adoc
# Extracted 158 elements from ../bluexp-dataset/cm/wf_gcp_ontap_create_vol_cifs.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_cloud_md_create_account.adoc
# Extracted 47 elements from ../bluexp-dataset/cm/wf_aws_cloud_md_create_account.adoc
# Processing file: ../bluexp-dataset/cm/workflow_processes.adoc
# Extracted 57 elements from ../bluexp-dataset/cm/workflow_processes.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_before.adoc
# Extracted 18 elements from ../bluexp-dataset/cm/wf_common_before.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_identity_get_nss_keys.adoc
# Extracted 66 elements from ../bluexp-dataset/cm/wf_common_identity_get_nss_keys.adoc
# Processing file: ../bluexp-dataset/cm/wf_cvo_before.adoc
# Extracted 21 elements from ../bluexp-dataset/cm/wf_cvo_before.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_ontap_delete_cifs.adoc
# Extracted 70 elements from ../bluexp-dataset/cm/wf_gcp_ontap_delete_cifs.adoc
# Processing file: ../bluexp-dataset/cm/wf_azuregcp_ontap_create_aggr.adoc
# Extracted 46 elements from ../bluexp-dataset/cm/wf_azuregcp_ontap_create_aggr.adoc
# Processing file: ../bluexp-dataset/cm/wf_common_ontap_md_get_snapmirror_svm_policies.adoc
# Extracted 24 elements from ../bluexp-dataset/cm/wf_common_ontap_md_get_snapmirror_svm_policies.adoc
# Processing file: ../bluexp-dataset/cm/wf_gcp_cloud_md_get_packages.adoc
# Extracted 219 elements from ../bluexp-dataset/cm/wf_gcp_cloud_md_get_packages.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_ontap_create_cifs.adoc
# Extracted 137 elements from ../bluexp-dataset/cm/wf_azure_ontap_create_cifs.adoc
# Processing file: ../bluexp-dataset/cm/wf_aws_cloud_md_get_vpcs.adoc
# Extracted 51 elements from ../bluexp-dataset/cm/wf_aws_cloud_md_get_vpcs.adoc
# Processing file: ../bluexp-dataset/cm/wf_azure_cloud_md_get_regions.adoc
# Extracted 122 elements from ../bluexp-dataset/cm/wf_azure_cloud_md_get_regions.adoc
# Processing file: ../bluexp-dataset/cm/wf_onprem_ontap_delete_volume.adoc
# Extracted 38 elements from ../bluexp-dataset/cm/wf_onprem_ontap_delete_volume.adoc
# Processing file: ../bluexp-dataset/credential/credential.json
# Extracted 1091 elements from ../bluexp-dataset/credential/credential.json
# Processing file: ../bluexp-dataset/credential/credential-x-doc.json
# Extracted 134 elements from ../bluexp-dataset/credential/credential-x-doc.json
# Processing file: ../bluexp-dataset/cbs/cbs-x-doc.json
# Extracted 830 elements from ../bluexp-dataset/cbs/cbs-x-doc.json
# Processing file: ../bluexp-dataset/cbs/cbs.json
# Extracted 8217 elements from ../bluexp-dataset/cbs/cbs.json
# Processing file: ../bluexp-dataset/ipa/ipa-x-doc.json
# Extracted 299 elements from ../bluexp-dataset/ipa/ipa-x-doc.json
# Processing file: ../bluexp-dataset/ipa/ipa.json
# Extracted 2498 elements from ../bluexp-dataset/ipa/ipa.json
# Processing file: ../bluexp-dataset/tenancy/tenancy-x-doc.json
# Extracted 512 elements from ../bluexp-dataset/tenancy/tenancy-x-doc.json
# Processing file: ../bluexp-dataset/tenancy/tenancy.json
# Extracted 3422 elements from ../bluexp-dataset/tenancy/tenancy.json
# Processing file: ../bluexp-dataset/copysync/copysync-x-doc.json
# Extracted 991 elements from ../bluexp-dataset/copysync/copysync-x-doc.json
# Processing file: ../bluexp-dataset/copysync/copysync.json
# Extracted 17778 elements from ../bluexp-dataset/copysync/copysync.json
# Processing file: ../bluexp-dataset/fsx/fsx.json
# Extracted 1773 elements from ../bluexp-dataset/fsx/fsx.json
# Processing file: ../bluexp-dataset/fsx/fsx-x-doc.json
# Extracted 176 elements from ../bluexp-dataset/fsx/fsx-x-doc.json
# Processing file: ../bluexp-dataset/audit/audit.json
# Extracted 448 elements from ../bluexp-dataset/audit/audit.json
# Processing file: ../bluexp-dataset/audit/audit-x-doc.json
# Extracted 34 elements from ../bluexp-dataset/audit/audit-x-doc.json
# Processing file: ../bluexp-dataset/dw/dw.json
# Extracted 2744 elements from ../bluexp-dataset/dw/dw.json
# Processing file: ../bluexp-dataset/dw/dw-x-doc.json
# Extracted 213 elements from ../bluexp-dataset/dw/dw-x-doc.json
# Processing file: ../bluexp-dataset/tenancyv4/tenancyv4.yaml
# Extracted 11278 elements from ../bluexp-dataset/tenancyv4/tenancyv4.yaml
# Processing file: ../bluexp-dataset/_index.yml
# Extracted 68 elements from ../bluexp-dataset/_index.yml
# Processing file: ../bluexp-dataset/project.yml
# Extracted 35 elements from ../bluexp-dataset/project.yml
# Processing file: ../bluexp-dataset/api-cm/sidebar.yml
# Extracted 322 elements from ../bluexp-dataset/api-cm/sidebar.yml
# Processing file: ../bluexp-dataset/credential/sidebar.yml
# Extracted 3 elements from ../bluexp-dataset/credential/sidebar.yml
# Processing file: ../bluexp-dataset/cbs/sidebar.yml
# Extracted 3 elements from ../bluexp-dataset/cbs/sidebar.yml
# Processing file: ../bluexp-dataset/ipa/sidebar.yml
# Extracted 3 elements from ../bluexp-dataset/ipa/sidebar.yml
# Processing file: ../bluexp-dataset/tenancy/sidebar.yml
# Extracted 3 elements from ../bluexp-dataset/tenancy/sidebar.yml
# Processing file: ../bluexp-dataset/platform/sidebar.yml
# Extracted 29 elements from ../bluexp-dataset/platform/sidebar.yml
# Processing file: ../bluexp-dataset/workflows/sidebar.yml
# Extracted 13 elements from ../bluexp-dataset/workflows/sidebar.yml
# Processing file: ../bluexp-dataset/copysync/sidebar.yml
# Extracted 3 elements from ../bluexp-dataset/copysync/sidebar.yml
# Processing file: ../bluexp-dataset/fsx/sidebar.yml
# Extracted 1 elements from ../bluexp-dataset/fsx/sidebar.yml
# Processing file: ../bluexp-dataset/audit/sidebar.yml
# Extracted 3 elements from ../bluexp-dataset/audit/sidebar.yml
# Processing file: ../bluexp-dataset/support/sidebar.yml
# Extracted 5 elements from ../bluexp-dataset/support/sidebar.yml
# Processing file: ../bluexp-dataset/automate/sidebar.yml
# Extracted 7 elements from ../bluexp-dataset/automate/sidebar.yml
# Processing file: ../bluexp-dataset/tenancyv4/sidebar.yml
# Extracted 3 elements from ../bluexp-dataset/tenancyv4/sidebar.yml
# Processing file: ../bluexp-dataset/tenancyv4/tenancyv4-x-doc.yml
# Extracted 1516 elements from ../bluexp-dataset/tenancyv4/tenancyv4-x-doc.yml
# Processing file: ../bluexp-dataset/dw/sidebar.yml
# Extracted 3 elements from ../bluexp-dataset/dw/sidebar.yml
# Processing file: ../bluexp-dataset/cm/sidebar.yml
# Extracted 8 elements from ../bluexp-dataset/cm/sidebar.yml

# %%
# Export cleaned_docs to JSON after unstructured processing
try:
    with open('cell_4_cleaned_unstructured_doc.json', 'w', encoding='utf-8') as f:
        json.dump(doc_element_results, f, indent=2, ensure_ascii=False)
    
    print(f"   ✅ Cleaned docs exported to 'cleaned_docs_final_v2.json'")
    print(f"   📄 File size: {Path('cleaned_docs_final.json').stat().st_size / 1024:.1f} KB")
    print(f"   📊 Contains {len(doc_element_results)} cleaned documents")
    
except Exception as e:
    print(f"   ❌ Error exporting cleaned_docs: {e}")
# Out:
#    ✅ Cleaned docs exported to 'cleaned_docs_final_v2.json'
#    ❌ Error exporting cleaned_docs: [Errno 2] No such file or directory: 'cleaned_docs_final.json'

# %% [markdown]
# ## Load documents into a vector db

# %%
client = chromadb.PersistentClient(path="chroma_tmp", settings=chromadb.Settings(allow_reset=True))
client.reset()
# Out:
# True

# %%
# Create a new collection named "winter_sports" using the client object.
# The collection is configured with metadata specifying the similarity metric
# for the HNSW (Hierarchical Navigable Small World) algorithm as "cosine".
# "cosine" is typically used to measure the similarity between vectors.
ollection = client.create_collection(
    name="winter_sports",
    metadata={"hnsw:space": "cosine"}
)

# %%
import json
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor

def process_document(doc):
    try:
        specific_metadata = {
            "file_directory": doc['metadata'].get("file_directory"),
            "filename": doc['metadata'].get("filename"),
            "filetype": doc['metadata'].get("filetype")
        }
        collection.add(
            documents=[doc['text']],
            metadatas=[specific_metadata],
            ids=doc["element_id"]
        )
    except Exception as e:
        print(f"Error adding document: {e}")

# Increase the number of threads
MAX_THREADS = 10  # Adjust this value based on your system's capabilities

with ThreadPoolExecutor(max_workers=MAX_THREADS) as executor:
    list(tqdm(executor.map(process_document, doc_element_results), total=len(doc_element_results), desc="Processing documents"))
# Out:
# Processing documents:   3%|▎         | 2796/86063 [04:01<11:47:50,  1.96it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:   7%|▋         | 5953/86063 [08:01<8:46:18,  2.54it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  14%|█▍        | 11920/86063 [16:10<10:55:48,  1.88it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  21%|██        | 17931/86063 [24:10<7:05:13,  2.67it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  31%|███▏      | 27043/86063 [36:17<1:14:38, 13.18it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  35%|███▍      | 30039/86063 [40:19<1:51:15,  8.39it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  45%|████▌     | 38809/86063 [52:30<4:49:46,  2.72it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
#
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  49%|████▉     | 42043/86063 [56:34<3:08:03,  3.90it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  52%|█████▏    | 44960/86063 [1:00:39<4:13:30,  2.70it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  59%|█████▉    | 51090/86063 [1:40:37<04:59, 116.63it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  63%|██████▎   | 54096/86063 [1:44:35<18:06, 29.42it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
#
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  66%|██████▋   | 57105/86063 [1:48:33<10:15, 47.05it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  73%|███████▎  | 63114/86063 [1:59:06<10:05, 37.88it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  77%|███████▋  | 66128/86063 [2:04:15<04:47, 69.31it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  84%|████████▎ | 72052/86063 [2:14:39<2:26:55,  1.59it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  87%|████████▋ | 75111/86063 [2:19:43<05:37, 32.46it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  91%|█████████ | 78009/86063 [2:25:02<55:50,  2.40it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  94%|█████████▍| 81102/86063 [2:30:08<02:34, 32.07it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents:  98%|█████████▊| 84154/86063 [2:35:26<00:26, 72.66it/s]
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Error adding document: '8a1521f0-d952-44c4-8f4d-99b77570579aCollectionAddEvent'
# Processing documents: 100%|██████████| 86063/86063 [2:38:42<00:00,  9.04it/s]

# %% [markdown]
# ## See the elements in Vector DB

# %%
results = collection.peek()
print(results["documents"])
# Out:
# ['--- sidebar: sidebar permalink: legal-notices.html keywords: copyrights, notice, trademarks, patents, privacy, open source summary: Legal notices provide access to copyright statements, trademarks, patents, and more. ---', ':nofooter:', ':imagesdir: ./media/', ':hardbreaks:', '// Include the common notices include::https://raw.githubusercontent.com/NetAppDocs/common/main/_include/common-legal-notices.adoc[]', '= Legal notices', '[.lead]', '--- sidebar: sidebar permalink: platform/aa_concepts.html keywords: bluexp, authorization, authentication, oauth2.0, access tokens, rest, apis summary: You should be familiar with the basic authentication and authorization concepts before using the BlueXP REST APIs. ---', ':linkattrs:', '[.lead] You should be familiar with the basic authentication and authorization concepts before using the BlueXP REST APIs.']

# %% [markdown]
# ## Perform a hybrid search with metadata

# %%
result = collection.query(
    query_texts=["How do i setup auth for bluexp?"],
    n_results=5
)

print(json.dumps(result, indent=2))
# Out:
# {
#   "ids": [
#     [
#       "901ae61b122c1572f9f39bb9e6b81535",
#       "cb52a897d83f690d8f6acbffa0905b63",
#       "ef19837a8ce5bb716956c72994b89c9a",
#       "7cd85525616841d7226e13a58206b89a",
#       "99ba15e14646096104dc1dc7061e7cc7"
#     ]
#   ],
#   "embeddings": null,
#   "documents": [
#     [
#       "Authentication resources You need to authenticate using a BlueXP account to run the API operations.",
#       "bxp_bearer_auth:",
#       "All NetApp BlueXP services use OAuth 2.0 for authorization. OAuth 2.0 is an open standard implemented by several authorization providers including *Auth0*. Connecting and communicating with a secure REST endpoint is a two-step process:",
#       "bxp_bearer_auth: []",
#       ".Have BlueXP credentials You'll need a NetApp account to acquire an access token required to issue the REST API calls."
#     ]
#   ],
#   "uris": null,
#   "included": [
#     "metadatas",
#     "documents",
#     "distances"
#   ],
#   "data": null,
#   "metadatas": [
#     [
#       {
#         "filetype": "text/plain",
#         "file_directory": "../bluexp-dataset/cm",
#         "filename": "overview.adoc"
#       },
#       {
#         "filetype": "text/plain",
#         "filename": "tenancyv4.yaml",
#         "file_directory": "../bluexp-dataset/tenancyv4"
#       },
#       {
#         "file_directory": "../bluexp-dataset/cm",
#         "filename": "security.adoc",
#         "filetype": "text/plain"
#       },
#       {
#         "filename": "tenancyv4.yaml",
#         "filetype": "text/plain",
#         "file_directory": "../bluexp-dataset/tenancyv4"
#       },
#       {
#         "filetype": "text/plain",
#         "filename": "prepare.adoc",
#         "file_directory": "../bluexp-dataset/cm"
#       }
#     ]
#   ],
#   "distances": [
#     [
#       0.2123926281929016,
#       0.270855188369751,
#       0.2761651277542114,
#       0.3134831190109253,
#       0.3499101996421814
#     ]
#   ]
# }
